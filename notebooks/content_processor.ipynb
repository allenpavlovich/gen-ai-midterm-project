# %% [markdown]
# # UChicago MS in Applied Data Science Website - Content Processor
#
# This notebook handles Phase 2 of the scraping process: processing the previously discovered links and converting their content to Markdown format.

# %%
# Import required libraries
import os
import re
import json
import requests
from bs4 import BeautifulSoup
from markdownify import markdownify as md
from urllib.parse import urlparse
import time
import logging
import pandas as pd
from datetime import datetime

# %%
# Configuration
BASE_URL = "https://datascience.uchicago.edu/"
DATA_DIR = "../data"
MARKDOWN_DIR = os.path.join(DATA_DIR, "markdown")
LOGS_DIR = "../logs"
LINKS_FILE = os.path.join(DATA_DIR, "discovered_links.json")
PROCESSED_FILE = os.path.join(DATA_DIR, "processed_links.json")
DELAY = 1  # Reduced delay between requests (in seconds)

# Create output directories if they don't exist
os.makedirs(MARKDOWN_DIR, exist_ok=True)
os.makedirs(LOGS_DIR, exist_ok=True)

# %%
# Setup logging
log_file = os.path.join(LOGS_DIR, f"content_processor_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log")
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file),
        logging.StreamHandler()  # Also log to console
    ]
)
logger = logging.getLogger()

# %%
def load_discovered_links():
    """
    Load the previously discovered links from the JSON file
    """
    if not os.path.exists(LINKS_FILE):
        logger.error(f"Links file not found: {LINKS_FILE}")
        return []
    
    with open(LINKS_FILE, 'r') as f:
        data = json.load(f)
    
    logger.info(f"Loaded {len(data['links'])} links discovered on {data['discovery_date']}")
    return data['links']

# %%
def get_page_content(url):
    """
    Fetch the content of a page
    """
    try:
        response = requests.get(url, headers={
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36'
        }, timeout=10)
        response.raise_for_status()
        return response.text
    except Exception as e:
        logger.error(f"Error fetching {url}: {e}")
        return None

# %%
def get_title(soup):
    """
    Extract the title from a BeautifulSoup object
    """
    if soup.title and soup.title.string:
        return soup.title.string.strip()
    
    # Fallback to h1
    h1 = soup.find('h1')
    if h1 and h1.get_text():
        return h1.get_text().strip()
    
    return "No Title"

# %%
def get_main_content(soup):
    """
    Extract the main content from a BeautifulSoup object
    """
    # Try to find the main content based on common HTML5 elements or UChicago specific patterns
    content_candidates = [
        soup.find('main'),
        soup.find('article'),
        soup.find('div', {'class': 'entry-content'}),
        soup.find('div', {'class': 'content'}),
        soup.find('div', {'id': 'content'}),
        soup.find('div', {'class': 'container'}),
        soup.find('div', {'class': re.compile(r'main-content')})
    ]
    
    # Use the first non-None candidate
    for candidate in content_candidates:
        if candidate:
            return candidate
    
    # If no candidates found, return the body
    return soup.body if soup.body else soup

# %%
def extract_category(url):
    """
    Extract a category from the URL for better organization
    """
    parsed = urlparse(url)
    path = parsed.path.strip('/')
    
    # If the path is empty, it's the homepage
    if not path:
        return 'homepage'
    
    # Extract the first part of the path as the category
    parts = path.split('/')
    if len(parts) > 0:
        return parts[0]
    
    return 'uncategorized'

# %%
def html_to_markdown(html_content, url, preserve_tables=True, extract_img_alt=True):
    """
    Convert HTML to Markdown, with special handling for tables and images
    """
    # Custom options to preserve tables
    options = {
        'strip': ['script', 'style'],
        'heading_style': 'atx',
        'bullets': '*',
        'code_language': 'python'
    }
    
    soup = BeautifulSoup(html_content, 'html.parser')
    
    if extract_img_alt:
        # Extract alt text from images to preserve information
        for img in soup.find_all('img'):
            alt_text = img.get('alt', '').strip()
            if alt_text:
                # Create a text node with image description
                img_desc = soup.new_tag('p')
                img_desc.string = f"[Image: {alt_text}]"
                img.insert_after(img_desc)
    
    if preserve_tables:
        # Process all tables
        for table in soup.find_all('table'):
            # Create a list to store table data
            markdown_table = []
            rows = table.find_all('tr')
            
            if not rows:
                continue
                
            # Process header row
            header_cells = rows[0].find_all(['th', 'td'])
            if header_cells:
                header = ['| ' + cell.get_text().strip() for cell in header_cells]
                markdown_table.append(''.join(header) + ' |')
                markdown_table.append('|' + '---|' * len(header_cells))
            
            # Process data rows
            for row in rows[1:] if header_cells else rows:
                cells = row.find_all('td')
                if cells:
                    data_row = ['| ' + cell.get_text().strip() for cell in cells]
                    markdown_table.append(''.join(data_row) + ' |')
            
            # Replace the table with our markdown version
            if markdown_table:
                new_tag = soup.new_tag('div')
                new_tag.string = '\n'.join(markdown_table)
                table.replace_with(new_tag)
        
        # Also look for div-based tables (common in modern sites)
        # This is a simplified approach - might need customization for specific layouts
        table_divs = soup.find_all('div', class_=re.compile(r'(table|grid)'))
        for div in table_divs:
            # Add a comment to mark this as a table-like structure
            comment = soup.new_string('\n\n<!-- Table-like structure detected -->\n\n')
            div.insert_before(comment)
    
    # Extract breadcrumb navigation if present
    breadcrumbs = soup.find_all(['nav', 'div'], class_=re.compile(r'(breadcrumb)'))
    breadcrumb_text = ''
    if breadcrumbs:
        crumbs = []
        for bc in breadcrumbs:
            links = bc.find_all('a')
            if links:
                crumbs = [link.get_text().strip() for link in links]
                breadcrumb_text = ' > '.join(crumbs)
                break
    
    # Convert to markdown
    markdown = md(str(soup), **options)
    
    # Clean up the markdown
    markdown = re.sub(r'\n{3,}', '\n\n', markdown)  # Remove excess newlines
    markdown = re.sub(r'\[\s*\]\(([^)]+)\)', '', markdown)  # Remove empty links
    
    # Add breadcrumbs metadata if found
    if breadcrumb_text:
        breadcrumb_meta = f"\n\nBreadcrumb: {breadcrumb_text}\n\n"
        markdown = breadcrumb_meta + markdown
    
    return markdown

# %%
def save_markdown(title, content, url, category):
    """
    Save markdown content to a file with useful metadata
    """
    # Create a valid filename from the URL
    parsed_url = urlparse(url)
    path = parsed_url.path.strip('/')
    path = path.replace('/', '_')
    
    if not path:
        path = 'index'
    
    filename = f"{path}.md"
    filepath = os.path.join(MARKDOWN_DIR, filename)
    
    # Add frontmatter with metadata
    frontmatter = f"---\ntitle: {title}\noriginal_url: {url}\ncategory: {category}\ndate: {datetime.now().strftime('%Y-%m-%d')}\n---\n\n"
    
    with open(filepath, 'w', encoding='utf-8') as f:
        f.write(frontmatter + content)
    
    logger.info(f"Saved {filepath}")
    return filepath

# %%
def save_processing_status(processed_urls, failed_urls):
    """
    Save the processing status to a JSON file
    """
    data = {
        'processing_date': datetime.now().isoformat(),
        'processed_count': len(processed_urls),
        'failed_count': len(failed_urls),
        'processed_urls': processed_urls,
        'failed_urls': failed_urls
    }
    
    with open(PROCESSED_FILE, 'w') as f:
        json.dump(data, f, indent=2)
    
    logger.info(f"Saved processing status to {PROCESSED_FILE}")
    return PROCESSED_FILE

# %%
def process_content():
    """
    Process the content of the discovered links
    """
    # Load discovered links
    links = load_discovered_links()
    if not links:
        logger.error("No links to process")
        return
    
    processed_urls = []
    failed_urls = []
    url_to_file = {}
    
    total_links = len(links)
    logger.info(f"Starting to process {total_links} links")
    
    for i, url in enumerate(links):
        logger.info(f"Processing {i+1}/{total_links}: {url}")
        
        # Fetch the page content
        html_content = get_page_content(url)
        if not html_content:
            logger.warning(f"Failed to get content for {url}")
            failed_urls.append(url)
            continue
        
        try:
            # Parse the HTML
            soup = BeautifulSoup(html_content, 'html.parser')
            
            # Get the title
            title = get_title(soup)
            
            # Extract category
            category = extract_category(url)
            
            # Get the main content
            main_content = get_main_content(soup)
            
            # Convert to markdown
            markdown_content = html_to_markdown(str(main_content), url)
            
            # Save the markdown content
            local_file = save_markdown(title, markdown_content, url, category)
            url_to_file[url] = local_file
            processed_urls.append(url)
            
            # Periodically save progress (every 10 pages)
            if (i + 1) % 10 == 0:
                save_processing_status(processed_urls, failed_urls)
                
        except Exception as e:
            logger.error(f"Error processing {url}: {e}")
            failed_urls.append(url)
        
        # Sleep to avoid overloading the server
        time.sleep(DELAY)
    
    # Save final processing status
    save_processing_status(processed_urls, failed_urls)
    
    return {
        'processed_count': len(processed_urls),
        'failed_count': len(failed_urls),
        'url_to_file': url_to_file
    }

# %%
# Execute the content processing
logger.info("Starting content processing...")
start_time = time.time()

results = process_content()

end_time = time.time()
elapsed_time = end_time - start_time
logger.info(f"Content processing completed in {elapsed_time:.2f} seconds")

if results:
    logger.info(f"Processed: {results['processed_count']} pages")
    logger.info(f"Failed: {results['failed_count']} pages")
# Out:
# 2025-05-04 17:48:17,483 - INFO - Starting content processing...
# 2025-05-04 17:48:17,485 - INFO - Loaded 1414 links discovered on 2025-05-04T16:53:47.334212
# 2025-05-04 17:48:17,486 - INFO - Starting to process 1414 links
# 2025-05-04 17:48:17,487 - INFO - Processing 1/1414: https://datascience.uchicago.edu/research/ai-science/people
# 2025-05-04 17:48:18,575 - INFO - Saved ../data\markdown\research_ai-science_people.md
# 2025-05-04 17:48:19,576 - INFO - Processing 2/1414: https://datascience.uchicago.edu/people/rajvi-shah
# 2025-05-04 17:48:20,483 - INFO - Saved ../data\markdown\people_rajvi-shah.md
# 2025-05-04 17:48:21,486 - INFO - Processing 3/1414: https://datascience.uchicago.edu/people/olivia-morkved
# 2025-05-04 17:48:22,416 - INFO - Saved ../data\markdown\people_olivia-morkved.md
# 2025-05-04 17:48:23,418 - INFO - Processing 4/1414: https://datascience.uchicago.edu/people/mengzhan-jhan-liufu
# 2025-05-04 17:48:24,430 - INFO - Saved ../data\markdown\people_mengzhan-jhan-liufu.md
# 2025-05-04 17:48:25,432 - INFO - Processing 5/1414: https://datascience.uchicago.edu/people/jennifer-wei-mem
# 2025-05-04 17:48:26,370 - INFO - Saved ../data\markdown\people_jennifer-wei-mem.md
# 2025-05-04 17:48:27,371 - INFO - Processing 6/1414: https://datascience.uchicago.edu/research/data-democracy-initiative
# 2025-05-04 17:48:30,099 - ERROR - Error fetching https://datascience.uchicago.edu/research/data-democracy-initiative: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/research/data-democracy-initiative
# 2025-05-04 17:48:30,101 - WARNING - Failed to get content for https://datascience.uchicago.edu/research/data-democracy-initiative
# 2025-05-04 17:48:30,103 - INFO - Processing 7/1414: https://datascience.uchicago.edu/people/elva-lu
# 2025-05-04 17:48:31,029 - INFO - Saved ../data\markdown\people_elva-lu.md
# 2025-05-04 17:48:32,031 - INFO - Processing 8/1414: https://datascience.uchicago.edu/people/oscar-leong
# 2025-05-04 17:48:32,956 - INFO - Saved ../data\markdown\people_oscar-leong.md
# 2025-05-04 17:48:33,958 - INFO - Processing 9/1414: https://datascience.uchicago.edu/people/kristin-haddadin-sheher
# 2025-05-04 17:48:34,962 - INFO - Saved ../data\markdown\people_kristin-haddadin-sheher.md
# 2025-05-04 17:48:35,965 - INFO - Processing 10/1414: https://datascience.uchicago.edu/people/ramanujan-srinath
# 2025-05-04 17:48:37,212 - INFO - Saved ../data\markdown\people_ramanujan-srinath.md
# 2025-05-04 17:48:37,214 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:48:38,216 - INFO - Processing 11/1414: mailto:jcfang@uchicago.edu
# 2025-05-04 17:48:38,219 - ERROR - Error fetching mailto:jcfang@uchicago.edu: No connection adapters were found for 'mailto:jcfang@uchicago.edu'
# 2025-05-04 17:48:38,220 - WARNING - Failed to get content for mailto:jcfang@uchicago.edu
# 2025-05-04 17:48:38,221 - INFO - Processing 12/1414: https://datascience.uchicago.edu/people/raul-castro-fernandez
# 2025-05-04 17:48:39,279 - INFO - Saved ../data\markdown\people_raul-castro-fernandez.md
# 2025-05-04 17:48:40,281 - INFO - Processing 13/1414: https://datascience.uchicago.edu/engage/fellowships
# 2025-05-04 17:48:41,461 - INFO - Saved ../data\markdown\engage_fellowships.md
# 2025-05-04 17:48:42,463 - INFO - Processing 14/1414: https://datascience.uchicago.edu/events/deciphering-cuneiform-with-artificial-intelligence
# 2025-05-04 17:48:43,449 - INFO - Saved ../data\markdown\events_deciphering-cuneiform-with-artificial-intelligence.md
# 2025-05-04 17:48:44,450 - INFO - Processing 15/1414: https://datascience.uchicago.edu/people/david-jacobson-he-him
# 2025-05-04 17:48:45,434 - INFO - Saved ../data\markdown\people_david-jacobson-he-him.md
# 2025-05-04 17:48:46,436 - INFO - Processing 16/1414: https://datascience.uchicago.edu/insights/debit-development-bank-investment-tracker
# 2025-05-04 17:48:47,448 - INFO - Saved ../data\markdown\insights_debit-development-bank-investment-tracker.md
# 2025-05-04 17:48:48,449 - INFO - Processing 17/1414: https://datascience.uchicago.edu/people/claire-donnat
# 2025-05-04 17:48:49,401 - INFO - Saved ../data\markdown\people_claire-donnat.md
# 2025-05-04 17:48:50,402 - INFO - Processing 18/1414: https://datascience.uchicago.edu/news/uchicago-data-science-institute-announces-founding-industry-affiliates
# 2025-05-04 17:48:51,411 - INFO - Saved ../data\markdown\news_uchicago-data-science-institute-announces-founding-industry-affiliates.md
# 2025-05-04 17:48:52,412 - INFO - Processing 19/1414: https://datascience.uchicago.edu/events/past-events
# 2025-05-04 17:48:53,433 - INFO - Saved ../data\markdown\events_past-events.md
# 2025-05-04 17:48:54,435 - INFO - Processing 20/1414: https://datascience.uchicago.edu/news/top-data-science-skills-employers-are-looking-for
# 2025-05-04 17:48:55,405 - INFO - Saved ../data\markdown\news_top-data-science-skills-employers-are-looking-for.md
# 2025-05-04 17:48:55,408 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:48:56,409 - INFO - Processing 21/1414: https://datascience.uchicago.edu/news/2023-rising-stars-in-data-science-visit-uchicago-to-advance-their-post-doctoral-careers
# 2025-05-04 17:48:57,403 - INFO - Saved ../data\markdown\news_2023-rising-stars-in-data-science-visit-uchicago-to-advance-their-post-doctoral-careers.md
# 2025-05-04 17:48:58,406 - INFO - Processing 22/1414: https://datascience.uchicago.edu/news/community-data-fellow-stephania-tello-zamudio-helps-broaden-internet-access-for-illinois-residents
# 2025-05-04 17:48:59,647 - INFO - Saved ../data\markdown\news_community-data-fellow-stephania-tello-zamudio-helps-broaden-internet-access-for-illinois-residents.md
# 2025-05-04 17:49:00,648 - INFO - Processing 23/1414: https://datascience.uchicago.edu/events/data-ethics-and-policy-conference-2024-governance-in-a-digital-world
# 2025-05-04 17:49:01,625 - INFO - Saved ../data\markdown\events_data-ethics-and-policy-conference-2024-governance-in-a-digital-world.md
# 2025-05-04 17:49:02,626 - INFO - Processing 24/1414: https://datascience.uchicago.edu/news/uchicago-launches-transform-accelerator-for-data-science-emerging-ai-startups
# 2025-05-04 17:49:03,595 - INFO - Saved ../data\markdown\news_uchicago-launches-transform-accelerator-for-data-science-emerging-ai-startups.md
# 2025-05-04 17:49:04,597 - INFO - Processing 25/1414: https://datascience.uchicago.edu/people/mikhail-khodak
# 2025-05-04 17:49:05,552 - INFO - Saved ../data\markdown\people_mikhail-khodak.md
# 2025-05-04 17:49:06,554 - INFO - Processing 26/1414: https://datascience.uchicago.edu/events/adam-klivans-ut-austin-testable-learning
# 2025-05-04 17:49:07,985 - INFO - Saved ../data\markdown\events_adam-klivans-ut-austin-testable-learning.md
# 2025-05-04 17:49:08,986 - INFO - Processing 27/1414: https://datascience.uchicago.edu/education/masters-programs/online-program
# 2025-05-04 17:49:09,998 - INFO - Saved ../data\markdown\education_masters-programs_online-program.md
# 2025-05-04 17:49:10,999 - INFO - Processing 28/1414: https://datascience.uchicago.edu/news/uchicago-london-colloquium-features-data-science-quantum-research
# 2025-05-04 17:49:11,923 - INFO - Saved ../data\markdown\news_uchicago-london-colloquium-features-data-science-quantum-research.md
# 2025-05-04 17:49:12,925 - INFO - Processing 29/1414: https://datascience.uchicago.edu/events/uchicago-spark-data-science-conference
# 2025-05-04 17:49:13,900 - INFO - Saved ../data\markdown\events_uchicago-spark-data-science-conference.md
# 2025-05-04 17:49:14,901 - INFO - Processing 30/1414: https://datascience.uchicago.edu/people/andrew-razborov
# 2025-05-04 17:49:16,094 - INFO - Saved ../data\markdown\people_andrew-razborov.md
# 2025-05-04 17:49:16,096 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:49:17,098 - INFO - Processing 31/1414: https://datascience.uchicago.edu/events/dsi-summer-lab-data-democracy
# 2025-05-04 17:49:18,203 - INFO - Saved ../data\markdown\events_dsi-summer-lab-data-democracy.md
# 2025-05-04 17:49:19,206 - INFO - Processing 32/1414: https://datascience.uchicago.edu/news/students-ranya-sharma-and-jaleel-drones-akins-return-to-dsi-for-2022-summer-lab
# 2025-05-04 17:49:21,681 - INFO - Saved ../data\markdown\news_students-ranya-sharma-and-jaleel-drones-akins-return-to-dsi-for-2022-summer-lab.md
# 2025-05-04 17:49:22,683 - INFO - Processing 33/1414: https://datascience.uchicago.edu/education/summerlab/alumni-and-projects
# 2025-05-04 17:49:23,631 - INFO - Saved ../data\markdown\education_summerlab_alumni-and-projects.md
# 2025-05-04 17:49:24,632 - INFO - Processing 34/1414: https://datascience.uchicago.edu/people/jonathan-huang
# 2025-05-04 17:49:25,835 - INFO - Saved ../data\markdown\people_jonathan-huang.md
# 2025-05-04 17:49:26,838 - INFO - Processing 35/1414: https://datascience.uchicago.edu/news/masters-in-applied-data-science-autumn-2023-capstone-winners
# 2025-05-04 17:49:27,786 - INFO - Saved ../data\markdown\news_masters-in-applied-data-science-autumn-2023-capstone-winners.md
# 2025-05-04 17:49:28,788 - INFO - Processing 36/1414: https://datascience.uchicago.edu/education/summerlab/2021-cohort
# 2025-05-04 17:49:30,047 - INFO - Saved ../data\markdown\education_summerlab_2021-cohort.md
# 2025-05-04 17:49:31,048 - INFO - Processing 37/1414: https://datascience.uchicago.edu/news/1-million-dollar-grant-awarded-to-truman-community-college-and-uchicago-data-science-institute-educational-training-program
# 2025-05-04 17:49:32,045 - INFO - Saved ../data\markdown\news_1-million-dollar-grant-awarded-to-truman-community-college-and-uchicago-data-science-institute-educational-training-program.md
# 2025-05-04 17:49:33,046 - INFO - Processing 38/1414: https://datascience.uchicago.edu/people/arjun-nitin-bhagoji
# 2025-05-04 17:49:34,027 - INFO - Saved ../data\markdown\people_arjun-nitin-bhagoji.md
# 2025-05-04 17:49:35,029 - INFO - Processing 39/1414: https://datascience.uchicago.edu/people/daniel-posmik-he-him
# 2025-05-04 17:49:36,053 - INFO - Saved ../data\markdown\people_daniel-posmik-he-him.md
# 2025-05-04 17:49:37,055 - INFO - Processing 40/1414: https://datascience.uchicago.edu/research/postdoctoral-programs/rising-stars
# 2025-05-04 17:49:38,020 - INFO - Saved ../data\markdown\research_postdoctoral-programs_rising-stars.md
# 2025-05-04 17:49:38,023 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:49:39,024 - INFO - Processing 41/1414: https://datascience.uchicago.edu/people/antoinette-raggs
# 2025-05-04 17:49:39,997 - INFO - Saved ../data\markdown\people_antoinette-raggs.md
# 2025-05-04 17:49:40,998 - INFO - Processing 42/1414: https://datascience.uchicago.edu/news/five-uchicago-scholars-awarded-prestigious-sloan-fellowships-in-2024
# 2025-05-04 17:49:42,005 - INFO - Saved ../data\markdown\news_five-uchicago-scholars-awarded-prestigious-sloan-fellowships-in-2024.md
# 2025-05-04 17:49:43,006 - INFO - Processing 43/1414: https://datascience.uchicago.edu/people/yuehaw-khoo
# 2025-05-04 17:49:43,931 - INFO - Saved ../data\markdown\people_yuehaw-khoo.md
# 2025-05-04 17:49:44,933 - INFO - Processing 44/1414: https://datascience.uchicago.edu/people/owen-melia
# 2025-05-04 17:49:45,915 - INFO - Saved ../data\markdown\people_owen-melia.md
# 2025-05-04 17:49:46,917 - INFO - Processing 45/1414: mailto:jmarques@uchicago.edu
# 2025-05-04 17:49:46,920 - ERROR - Error fetching mailto:jmarques@uchicago.edu: No connection adapters were found for 'mailto:jmarques@uchicago.edu'
# 2025-05-04 17:49:46,921 - WARNING - Failed to get content for mailto:jmarques@uchicago.edu
# 2025-05-04 17:49:46,926 - INFO - Processing 46/1414: https://datascience.uchicago.edu/events/cdac-discovery-grant-proposers-day
# 2025-05-04 17:49:47,924 - INFO - Saved ../data\markdown\events_cdac-discovery-grant-proposers-day.md
# 2025-05-04 17:49:48,927 - INFO - Processing 47/1414: https://datascience.uchicago.edu/people/ashmit-dutta-he-him
# 2025-05-04 17:49:49,880 - INFO - Saved ../data\markdown\people_ashmit-dutta-he-him.md
# 2025-05-04 17:49:50,881 - INFO - Processing 48/1414: https://datascience.uchicago.edu/outreach/data-science-for-social-impact-network/summer-experience/2024
# 2025-05-04 17:49:51,913 - INFO - Saved ../data\markdown\outreach_data-science-for-social-impact-network_summer-experience_2024.md
# 2025-05-04 17:49:52,915 - INFO - Processing 49/1414: https://datascience.uchicago.edu/people/abhilasha-ravichander
# 2025-05-04 17:49:54,118 - INFO - Saved ../data\markdown\people_abhilasha-ravichander.md
# 2025-05-04 17:49:55,119 - INFO - Processing 50/1414: https://hsdatasciencestudy.datascience.uchicago.edu/curriculum-overviews
# 2025-05-04 17:49:56,060 - INFO - Saved ../data\markdown\curriculum-overviews.md
# 2025-05-04 17:49:56,064 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:49:57,066 - INFO - Processing 51/1414: https://datascience.uchicago.edu/events/hae-kyung-im-uchicago-aiscience-schmidt-fellows-speaker-series
# 2025-05-04 17:49:58,025 - INFO - Saved ../data\markdown\events_hae-kyung-im-uchicago-aiscience-schmidt-fellows-speaker-series.md
# 2025-05-04 17:49:59,026 - INFO - Processing 52/1414: https://datascience.uchicago.edu/research/facebook-messenger-chatbot-for-surveys-and-intervention-testing
# 2025-05-04 17:49:59,931 - INFO - Saved ../data\markdown\research_facebook-messenger-chatbot-for-surveys-and-intervention-testing.md
# 2025-05-04 17:50:00,932 - INFO - Processing 53/1414: https://datascience.uchicago.edu/news/summer-2024-hackathon-winners-announced
# 2025-05-04 17:50:01,907 - INFO - Saved ../data\markdown\news_summer-2024-hackathon-winners-announced.md
# 2025-05-04 17:50:02,909 - INFO - Processing 54/1414: https://datascience.uchicago.edu/people/benjamin-stoddart-he-him
# 2025-05-04 17:50:03,917 - INFO - Saved ../data\markdown\people_benjamin-stoddart-he-him.md
# 2025-05-04 17:50:04,918 - INFO - Processing 55/1414: https://datascience.uchicago.edu/people/launa-greer
# 2025-05-04 17:50:05,911 - INFO - Saved ../data\markdown\people_launa-greer.md
# 2025-05-04 17:50:06,912 - INFO - Processing 56/1414: https://datascience.uchicago.edu/people/sendhil-mullainathan
# 2025-05-04 17:50:07,906 - INFO - Saved ../data\markdown\people_sendhil-mullainathan.md
# 2025-05-04 17:50:08,908 - INFO - Processing 57/1414: https://datascience.uchicago.edu/people/pan-xu
# 2025-05-04 17:50:10,607 - INFO - Saved ../data\markdown\people_pan-xu.md
# 2025-05-04 17:50:11,610 - INFO - Processing 58/1414: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/faqs
# 2025-05-04 17:50:12,593 - INFO - Saved ../data\markdown\education_masters-programs_ms-in-applied-data-science_faqs.md
# 2025-05-04 17:50:13,595 - INFO - Processing 59/1414: https://datascience.uchicago.edu/people/roma-bhattacharjee
# 2025-05-04 17:50:14,570 - INFO - Saved ../data\markdown\people_roma-bhattacharjee.md
# 2025-05-04 17:50:15,571 - INFO - Processing 60/1414: https://datascience.uchicago.edu/people/halli-lacanlale
# 2025-05-04 17:50:16,540 - INFO - Saved ../data\markdown\people_halli-lacanlale.md
# 2025-05-04 17:50:16,544 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:50:17,545 - INFO - Processing 61/1414: https://datascience.uchicago.edu/research/clinical-behavior-analysis-via-unsupervised-learning
# 2025-05-04 17:50:18,557 - INFO - Saved ../data\markdown\research_clinical-behavior-analysis-via-unsupervised-learning.md
# 2025-05-04 17:50:19,559 - INFO - Processing 62/1414: https://datascience.uchicago.edu/people/yian-yin
# 2025-05-04 17:50:20,535 - INFO - Saved ../data\markdown\people_yian-yin.md
# 2025-05-04 17:50:21,536 - INFO - Processing 63/1414: https://datascience.uchicago.edu/events/ask-a-student-in-ms-in-applied-data-science-11
# 2025-05-04 17:50:22,509 - INFO - Saved ../data\markdown\events_ask-a-student-in-ms-in-applied-data-science-11.md
# 2025-05-04 17:50:23,511 - INFO - Processing 64/1414: https://datascience.uchicago.edu/events/ask-a-student-in-ms-in-applied-data-science-8
# 2025-05-04 17:50:24,707 - INFO - Saved ../data\markdown\events_ask-a-student-in-ms-in-applied-data-science-8.md
# 2025-05-04 17:50:25,709 - INFO - Processing 65/1414: https://datascience.uchicago.edu/research/understanding-and-auditing-content-moderation-policies
# 2025-05-04 17:50:26,659 - INFO - Saved ../data\markdown\research_understanding-and-auditing-content-moderation-policies.md
# 2025-05-04 17:50:27,661 - INFO - Processing 66/1414: https://datascience.uchicago.edu/outreach/data4all
# 2025-05-04 17:50:28,652 - INFO - Saved ../data\markdown\outreach_data4all.md
# 2025-05-04 17:50:29,654 - INFO - Processing 67/1414: https://datascience.uchicago.edu/people/yue-lin
# 2025-05-04 17:50:30,560 - INFO - Saved ../data\markdown\people_yue-lin.md
# 2025-05-04 17:50:31,562 - INFO - Processing 68/1414: https://datascience.uchicago.edu/people/ethan-truelove
# 2025-05-04 17:50:32,451 - INFO - Saved ../data\markdown\people_ethan-truelove.md
# 2025-05-04 17:50:33,453 - INFO - Processing 69/1414: https://datascience.uchicago.edu/people/utku-pamuksuz-phd
# 2025-05-04 17:50:34,415 - INFO - Saved ../data\markdown\people_utku-pamuksuz-phd.md
# 2025-05-04 17:50:35,421 - INFO - Processing 70/1414: https://datascience.uchicago.edu/news/ms-in-applied-data-science-students-present-research-at-national-conference
# 2025-05-04 17:50:36,378 - INFO - Saved ../data\markdown\news_ms-in-applied-data-science-students-present-research-at-national-conference.md
# 2025-05-04 17:50:36,380 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:50:37,381 - INFO - Processing 71/1414: https://datascience.uchicago.edu/news/uchicago-researchers-receive-grants-to-apply-computational-techniques-to-covid-fight
# 2025-05-04 17:50:38,367 - INFO - Saved ../data\markdown\news_uchicago-researchers-receive-grants-to-apply-computational-techniques-to-covid-fight.md
# 2025-05-04 17:50:39,369 - INFO - Processing 72/1414: https://datascience.uchicago.edu/people/manuel-mendez-diaz-he-him
# 2025-05-04 17:50:40,504 - INFO - Saved ../data\markdown\people_manuel-mendez-diaz-he-him.md
# 2025-05-04 17:50:41,506 - INFO - Processing 73/1414: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/instructors-staff
# 2025-05-04 17:50:42,784 - INFO - Saved ../data\markdown\education_masters-programs_ms-in-applied-data-science_instructors-staff.md
# 2025-05-04 17:50:43,786 - INFO - Processing 74/1414: https://datascience.uchicago.edu/news/uchicago-political-scientist-molly-offer-westort-named-carnegie-fellow
# 2025-05-04 17:50:44,746 - INFO - Saved ../data\markdown\news_uchicago-political-scientist-molly-offer-westort-named-carnegie-fellow.md
# 2025-05-04 17:50:45,747 - INFO - Processing 75/1414: https://datascience.uchicago.edu/news/grocery-gap-atlas-new-data-tool-visualizes-market-concentration-and-food-access-trends-across-the-u-s
# 2025-05-04 17:50:46,714 - INFO - Saved ../data\markdown\news_grocery-gap-atlas-new-data-tool-visualizes-market-concentration-and-food-access-trends-across-the-u-s.md
# 2025-05-04 17:50:47,716 - INFO - Processing 76/1414: https://datascience.uchicago.edu/events/storytelling-with-data-a-workshop-for-nonprofits
# 2025-05-04 17:50:48,632 - INFO - Saved ../data\markdown\events_storytelling-with-data-a-workshop-for-nonprofits.md
# 2025-05-04 17:50:49,634 - INFO - Processing 77/1414: mailto:huanqiuz@uchicago.edu
# 2025-05-04 17:50:49,635 - ERROR - Error fetching mailto:huanqiuz@uchicago.edu: No connection adapters were found for 'mailto:huanqiuz@uchicago.edu'
# 2025-05-04 17:50:49,636 - WARNING - Failed to get content for mailto:huanqiuz@uchicago.edu
# 2025-05-04 17:50:49,637 - INFO - Processing 78/1414: https://datascience.uchicago.edu/people/adam-fouda
# 2025-05-04 17:50:50,618 - INFO - Saved ../data\markdown\people_adam-fouda.md
# 2025-05-04 17:50:51,620 - INFO - Processing 79/1414: https://datascience.uchicago.edu/people/amir-jina
# 2025-05-04 17:50:52,583 - INFO - Saved ../data\markdown\people_amir-jina.md
# 2025-05-04 17:50:53,585 - INFO - Processing 80/1414: https://debit.datascience.uchicago.edu/about
# 2025-05-04 17:50:54,123 - INFO - Saved ../data\markdown\about.md
# 2025-05-04 17:50:54,128 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:50:55,130 - INFO - Processing 81/1414: https://datascience.uchicago.edu/news/david-uminsky-brings-data-science-education-experience-to-uchicago-initiatives
# 2025-05-04 17:50:56,116 - INFO - Saved ../data\markdown\news_david-uminsky-brings-data-science-education-experience-to-uchicago-initiatives.md
# 2025-05-04 17:50:57,118 - INFO - Processing 82/1414: https://datascience.uchicago.edu/people/diamon-dunlap-she-her
# 2025-05-04 17:50:58,051 - INFO - Saved ../data\markdown\people_diamon-dunlap-she-her.md
# 2025-05-04 17:50:59,052 - INFO - Processing 83/1414: https://datascience.uchicago.edu/news/sixteen-uchicago-faculty-members-receive-named-distinguished-service-professorships
# 2025-05-04 17:51:00,078 - INFO - Saved ../data\markdown\news_sixteen-uchicago-faculty-members-receive-named-distinguished-service-professorships.md
# 2025-05-04 17:51:01,080 - INFO - Processing 84/1414: https://datascience.uchicago.edu/people/jeanette-shutay-phd
# 2025-05-04 17:51:02,031 - INFO - Saved ../data\markdown\people_jeanette-shutay-phd.md
# 2025-05-04 17:51:03,033 - INFO - Processing 85/1414: https://datascience.uchicago.edu/people/maria-juaristi-she-her
# 2025-05-04 17:51:03,994 - INFO - Saved ../data\markdown\people_maria-juaristi-she-her.md
# 2025-05-04 17:51:04,996 - INFO - Processing 86/1414: https://datascience.uchicago.edu/people/michael-kremer
# 2025-05-04 17:51:05,970 - INFO - Saved ../data\markdown\people_michael-kremer.md
# 2025-05-04 17:51:06,971 - INFO - Processing 87/1414: https://datascience.uchicago.edu/people/dimitrios-tanoglidis
# 2025-05-04 17:51:07,911 - INFO - Saved ../data\markdown\people_dimitrios-tanoglidis.md
# 2025-05-04 17:51:08,913 - INFO - Processing 88/1414: https://datascience.uchicago.edu/news/ancient-language-processing-teaching-computers-to-read-cuneiform-tablets
# 2025-05-04 17:51:09,913 - INFO - Saved ../data\markdown\news_ancient-language-processing-teaching-computers-to-read-cuneiform-tablets.md
# 2025-05-04 17:51:10,915 - INFO - Processing 89/1414: https://datascience.uchicago.edu/people/pavithra-kamatchi-soundaram
# 2025-05-04 17:51:11,829 - INFO - Saved ../data\markdown\people_pavithra-kamatchi-soundaram.md
# 2025-05-04 17:51:12,831 - INFO - Processing 90/1414: https://datascience.uchicago.edu/people/gabrielle-lynn
# 2025-05-04 17:51:13,811 - INFO - Saved ../data\markdown\people_gabrielle-lynn.md
# 2025-05-04 17:51:13,814 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:51:14,815 - INFO - Processing 91/1414: https://datascience.uchicago.edu/people/hae-kyung-im
# 2025-05-04 17:51:15,759 - INFO - Saved ../data\markdown\people_hae-kyung-im.md
# 2025-05-04 17:51:16,761 - INFO - Processing 92/1414: https://datascience.uchicago.edu/people/varsha-etigunta
# 2025-05-04 17:51:17,742 - INFO - Saved ../data\markdown\people_varsha-etigunta.md
# 2025-05-04 17:51:18,744 - INFO - Processing 93/1414: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/career-outcomes
# 2025-05-04 17:51:19,699 - INFO - Saved ../data\markdown\education_masters-programs_ms-in-applied-data-science_career-outcomes.md
# 2025-05-04 17:51:20,701 - INFO - Processing 94/1414: mailto:liyading@uchicago.edu
# 2025-05-04 17:51:20,703 - ERROR - Error fetching mailto:liyading@uchicago.edu: No connection adapters were found for 'mailto:liyading@uchicago.edu'
# 2025-05-04 17:51:20,704 - WARNING - Failed to get content for mailto:liyading@uchicago.edu
# 2025-05-04 17:51:20,706 - INFO - Processing 95/1414: https://datascience.uchicago.edu/news/nsf-and-simons-foundation-launch-20-million-national-ai-research-institute-in-astronomy
# 2025-05-04 17:51:21,708 - INFO - Saved ../data\markdown\news_nsf-and-simons-foundation-launch-20-million-national-ai-research-institute-in-astronomy.md
# 2025-05-04 17:51:22,710 - INFO - Processing 96/1414: https://datascience.uchicago.edu/outreach/industry-partnerships/dsi-leadership-rooted-in-industry
# 2025-05-04 17:51:23,726 - INFO - Saved ../data\markdown\outreach_industry-partnerships_dsi-leadership-rooted-in-industry.md
# 2025-05-04 17:51:24,728 - INFO - Processing 97/1414: https://datascience.uchicago.edu/people/robert-rosner
# 2025-05-04 17:51:25,727 - INFO - Saved ../data\markdown\people_robert-rosner.md
# 2025-05-04 17:51:26,730 - INFO - Processing 98/1414: https://datascience.uchicago.edu/people/taishi-okano
# 2025-05-04 17:51:27,727 - INFO - Saved ../data\markdown\people_taishi-okano.md
# 2025-05-04 17:51:28,729 - INFO - Processing 99/1414: https://datascience.uchicago.edu/people/luis-m-a-bettencourt
# 2025-05-04 17:51:29,700 - INFO - Saved ../data\markdown\people_luis-m-a-bettencourt.md
# 2025-05-04 17:51:30,701 - INFO - Processing 100/1414: https://datascience.uchicago.edu/news-events/past-events
# 2025-05-04 17:51:32,261 - ERROR - Error fetching https://datascience.uchicago.edu/news-events/past-events: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/news-events/past-events
# 2025-05-04 17:51:32,262 - WARNING - Failed to get content for https://datascience.uchicago.edu/news-events/past-events
# 2025-05-04 17:51:32,263 - INFO - Processing 101/1414: https://datascience.uchicago.edu/people/olukunle-owolabi
# 2025-05-04 17:51:33,193 - INFO - Saved ../data\markdown\people_olukunle-owolabi.md
# 2025-05-04 17:51:34,195 - INFO - Processing 102/1414: https://datascience.uchicago.edu/news/two-uchicago-startups-receive-investment-from-the-george-shultz-innovation-fund
# 2025-05-04 17:51:35,166 - INFO - Saved ../data\markdown\news_two-uchicago-startups-receive-investment-from-the-george-shultz-innovation-fund.md
# 2025-05-04 17:51:36,167 - INFO - Processing 103/1414: https://datascience.uchicago.edu
# 2025-05-04 17:51:37,168 - INFO - Saved ../data\markdown\index.md
# 2025-05-04 17:51:38,170 - INFO - Processing 104/1414: mailto:ganghua@uchicago.edu
# 2025-05-04 17:51:38,175 - ERROR - Error fetching mailto:ganghua@uchicago.edu: No connection adapters were found for 'mailto:ganghua@uchicago.edu'
# 2025-05-04 17:51:38,177 - WARNING - Failed to get content for mailto:ganghua@uchicago.edu
# 2025-05-04 17:51:38,178 - INFO - Processing 105/1414: https://datascience.uchicago.edu/events/sam-kriegman-northwestern-aiscience-schmidt-fellows-speaker-series
# 2025-05-04 17:51:39,156 - INFO - Saved ../data\markdown\events_sam-kriegman-northwestern-aiscience-schmidt-fellows-speaker-series.md
# 2025-05-04 17:51:40,157 - INFO - Processing 106/1414: https://datascience.uchicago.edu/people/chenhao-tan
# 2025-05-04 17:51:41,132 - INFO - Saved ../data\markdown\people_chenhao-tan.md
# 2025-05-04 17:51:42,133 - INFO - Processing 107/1414: https://datascience.uchicago.edu/11th-hour-project
# 2025-05-04 17:51:43,394 - INFO - Saved ../data\markdown\11th-hour-project.md
# 2025-05-04 17:51:44,395 - INFO - Processing 108/1414: https://datascience.uchicago.edu/people/maxine-king
# 2025-05-04 17:51:45,373 - INFO - Saved ../data\markdown\people_maxine-king.md
# 2025-05-04 17:51:46,375 - INFO - Processing 109/1414: https://datascience.uchicago.edu/events/nsf-workshop-on-data-driven-modeling-and-prediction-of-rare-and-extreme-events
# 2025-05-04 17:51:47,689 - INFO - Saved ../data\markdown\events_nsf-workshop-on-data-driven-modeling-and-prediction-of-rare-and-extreme-events.md
# 2025-05-04 17:51:48,691 - INFO - Processing 110/1414: mailto:mjfranklin@uchicago.edu
# 2025-05-04 17:51:48,694 - ERROR - Error fetching mailto:mjfranklin@uchicago.edu: No connection adapters were found for 'mailto:mjfranklin@uchicago.edu'
# 2025-05-04 17:51:48,695 - WARNING - Failed to get content for mailto:mjfranklin@uchicago.edu
# 2025-05-04 17:51:48,697 - INFO - Processing 111/1414: https://datascience.uchicago.edu/insights/spatial-immunity-a-new-perspective-enabled-by-computer-vision
# 2025-05-04 17:51:49,687 - INFO - Saved ../data\markdown\insights_spatial-immunity-a-new-perspective-enabled-by-computer-vision.md
# 2025-05-04 17:51:50,690 - INFO - Processing 112/1414: https://datascience.uchicago.edu/people/david-uminsky
# 2025-05-04 17:51:51,656 - INFO - Saved ../data\markdown\people_david-uminsky.md
# 2025-05-04 17:51:52,659 - INFO - Processing 113/1414: https://datascience.uchicago.edu/news/first-ever-data4all-workshop-nurtures-future-data-scientists-from-chicagos-south-side
# 2025-05-04 17:51:53,646 - INFO - Saved ../data\markdown\news_first-ever-data4all-workshop-nurtures-future-data-scientists-from-chicagos-south-side.md
# 2025-05-04 17:51:54,648 - INFO - Processing 114/1414: https://datascience.uchicago.edu/events/ms-in-applied-data-science-information-session-online-program-5
# 2025-05-04 17:51:55,621 - INFO - Saved ../data\markdown\events_ms-in-applied-data-science-information-session-online-program-5.md
# 2025-05-04 17:51:56,624 - INFO - Processing 115/1414: https://datascience.uchicago.edu/people/siddharth-mishra-sharma
# 2025-05-04 17:51:57,558 - INFO - Saved ../data\markdown\people_siddharth-mishra-sharma.md
# 2025-05-04 17:51:58,560 - INFO - Processing 116/1414: https://datascience.uchicago.edu/people/abigail-reynolds
# 2025-05-04 17:51:59,470 - INFO - Saved ../data\markdown\people_abigail-reynolds.md
# 2025-05-04 17:52:00,472 - INFO - Processing 117/1414: https://datascience.uchicago.edu/outreach/industry-partnerships
# 2025-05-04 17:52:01,435 - INFO - Saved ../data\markdown\outreach_industry-partnerships.md
# 2025-05-04 17:52:02,436 - INFO - Processing 118/1414: https://datascience.uchicago.edu/people/ruqi-zhang
# 2025-05-04 17:52:03,374 - INFO - Saved ../data\markdown\people_ruqi-zhang.md
# 2025-05-04 17:52:04,377 - INFO - Processing 119/1414: https://datascience.uchicago.edu/news/neurips-2023-award-winning-paper-by-dsi-faculty-bo-li-decodingtrust-provides-a-comprehensive-framework-for-assessing-trustworthiness-of-gpt-models
# 2025-05-04 17:52:05,294 - INFO - Saved ../data\markdown\news_neurips-2023-award-winning-paper-by-dsi-faculty-bo-li-decodingtrust-provides-a-comprehensive-framework-for-assessing-trustworthiness-of-gpt-models.md
# 2025-05-04 17:52:06,295 - INFO - Processing 120/1414: https://datascience.uchicago.edu/research/rational-protein-engineering-using-data-driven-generative-models
# 2025-05-04 17:52:07,233 - INFO - Saved ../data\markdown\research_rational-protein-engineering-using-data-driven-generative-models.md
# 2025-05-04 17:52:07,237 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:52:08,238 - INFO - Processing 121/1414: https://datascience.uchicago.edu/people/harlin-lee
# 2025-05-04 17:52:09,168 - INFO - Saved ../data\markdown\people_harlin-lee.md
# 2025-05-04 17:52:10,170 - INFO - Processing 122/1414: https://datascience.uchicago.edu/events/ask-a-student-in-ms-in-applied-data-science-6
# 2025-05-04 17:52:11,108 - INFO - Saved ../data\markdown\events_ask-a-student-in-ms-in-applied-data-science-6.md
# 2025-05-04 17:52:12,110 - INFO - Processing 123/1414: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/events-deadlines
# 2025-05-04 17:52:13,131 - INFO - Saved ../data\markdown\education_masters-programs_ms-in-applied-data-science_events-deadlines.md
# 2025-05-04 17:52:14,132 - INFO - Processing 124/1414: mailto:annebrown@uchicago.edu
# 2025-05-04 17:52:14,134 - ERROR - Error fetching mailto:annebrown@uchicago.edu: No connection adapters were found for 'mailto:annebrown@uchicago.edu'
# 2025-05-04 17:52:14,136 - WARNING - Failed to get content for mailto:annebrown@uchicago.edu
# 2025-05-04 17:52:14,137 - INFO - Processing 125/1414: https://datascience.uchicago.edu/people/molly-offer-westort
# 2025-05-04 17:52:15,036 - INFO - Saved ../data\markdown\people_molly-offer-westort.md
# 2025-05-04 17:52:16,038 - INFO - Processing 126/1414: https://datascience.uchicago.edu/news/jan-mrozowskis-path-from-industry-professional-to-teaching-in-the-ms-in-applied-data-science-program
# 2025-05-04 17:52:16,983 - INFO - Saved ../data\markdown\news_jan-mrozowskis-path-from-industry-professional-to-teaching-in-the-ms-in-applied-data-science-program.md
# 2025-05-04 17:52:17,985 - INFO - Processing 127/1414: https://datascience.uchicago.edu/outreach/data-science-for-social-impact-network
# 2025-05-04 17:52:18,983 - INFO - Saved ../data\markdown\outreach_data-science-for-social-impact-network.md
# 2025-05-04 17:52:19,985 - INFO - Processing 128/1414: https://datascience.uchicago.edu/people/ian-foster
# 2025-05-04 17:52:21,019 - INFO - Saved ../data\markdown\people_ian-foster.md
# 2025-05-04 17:52:22,020 - INFO - Processing 129/1414: https://datascience.uchicago.edu/people/marshini-chetty
# 2025-05-04 17:52:23,011 - INFO - Saved ../data\markdown\people_marshini-chetty.md
# 2025-05-04 17:52:24,013 - INFO - Processing 130/1414: https://datascience.uchicago.edu/people/callista-christ
# 2025-05-04 17:52:24,971 - INFO - Saved ../data\markdown\people_callista-christ.md
# 2025-05-04 17:52:24,977 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:52:25,978 - INFO - Processing 131/1414: https://datascience.uchicago.edu/news/assistant-professor-raul-castro-fernandez-awarded-nsf-career-grant-to-investigate-data-sharing-markets
# 2025-05-04 17:52:26,894 - INFO - Saved ../data\markdown\news_assistant-professor-raul-castro-fernandez-awarded-nsf-career-grant-to-investigate-data-sharing-markets.md
# 2025-05-04 17:52:27,895 - INFO - Processing 132/1414: https://datascience.uchicago.edu/news/new-dsi-faculty-haifeng-xu-brings-strategic-intelligence-to-neurips-2022
# 2025-05-04 17:52:28,885 - INFO - Saved ../data\markdown\news_new-dsi-faculty-haifeng-xu-brings-strategic-intelligence-to-neurips-2022.md
# 2025-05-04 17:52:29,887 - INFO - Processing 133/1414: https://datascience.uchicago.edu/people/elizabeth-barnes
# 2025-05-04 17:52:30,846 - INFO - Saved ../data\markdown\people_elizabeth-barnes.md
# 2025-05-04 17:52:31,848 - INFO - Processing 134/1414: https://datascience.uchicago.edu/research/ai-science/partnerships/center-for-living-systems
# 2025-05-04 17:52:32,802 - INFO - Saved ../data\markdown\research_ai-science_partnerships_center-for-living-systems.md
# 2025-05-04 17:52:33,804 - INFO - Processing 135/1414: https://datascience.uchicago.edu/news/ms-in-applied-data-science-staff-share-5-ways-to-instill-joy-in-higher-ed
# 2025-05-04 17:52:34,765 - INFO - Saved ../data\markdown\news_ms-in-applied-data-science-staff-share-5-ways-to-instill-joy-in-higher-ed.md
# 2025-05-04 17:52:35,767 - INFO - Processing 136/1414: https://datascience.uchicago.edu/events/cdac-distinguished-speaker-series-olga-russakovsky-princeton
# 2025-05-04 17:52:36,745 - INFO - Saved ../data\markdown\events_cdac-distinguished-speaker-series-olga-russakovsky-princeton.md
# 2025-05-04 17:52:37,747 - INFO - Processing 137/1414: https://datascience.uchicago.edu/people/amanda-coston
# 2025-05-04 17:52:38,680 - INFO - Saved ../data\markdown\people_amanda-coston.md
# 2025-05-04 17:52:39,681 - INFO - Processing 138/1414: https://datascience.uchicago.edu/people/kenthia-roberts
# 2025-05-04 17:52:40,626 - INFO - Saved ../data\markdown\people_kenthia-roberts.md
# 2025-05-04 17:52:41,628 - INFO - Processing 139/1414: https://datascience.uchicago.edu/news/six-uchicago-scientists-awarded-prestigious-sloan-fellowships-in-2025
# 2025-05-04 17:52:42,667 - INFO - Saved ../data\markdown\news_six-uchicago-scientists-awarded-prestigious-sloan-fellowships-in-2025.md
# 2025-05-04 17:52:43,669 - INFO - Processing 140/1414: https://datascience.uchicago.edu/people/tyler-skluzacek
# 2025-05-04 17:52:44,672 - INFO - Saved ../data\markdown\people_tyler-skluzacek.md
# 2025-05-04 17:52:44,676 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:52:45,678 - INFO - Processing 141/1414: https://datascience.uchicago.edu/people/bryan-choy
# 2025-05-04 17:52:46,603 - INFO - Saved ../data\markdown\people_bryan-choy.md
# 2025-05-04 17:52:47,605 - INFO - Processing 142/1414: https://datascience.uchicago.edu/people/lihua-lei
# 2025-05-04 17:52:48,588 - INFO - Saved ../data\markdown\people_lihua-lei.md
# 2025-05-04 17:52:49,590 - INFO - Processing 143/1414: https://datascience.uchicago.edu/news/meet-the-autumn-2019-cdac-discovery-grant-projects
# 2025-05-04 17:52:51,112 - INFO - Saved ../data\markdown\news_meet-the-autumn-2019-cdac-discovery-grant-projects.md
# 2025-05-04 17:52:52,114 - INFO - Processing 144/1414: https://datascience.uchicago.edu/people/john-chodera
# 2025-05-04 17:52:53,083 - INFO - Saved ../data\markdown\people_john-chodera.md
# 2025-05-04 17:52:54,084 - INFO - Processing 145/1414: https://datascience.uchicago.edu/events/dss-gari-clifford
# 2025-05-04 17:52:55,021 - INFO - Saved ../data\markdown\events_dss-gari-clifford.md
# 2025-05-04 17:52:56,023 - INFO - Processing 146/1414: mailto:sohamg@uchicago.edu
# 2025-05-04 17:52:56,024 - ERROR - Error fetching mailto:sohamg@uchicago.edu: No connection adapters were found for 'mailto:sohamg@uchicago.edu'
# 2025-05-04 17:52:56,026 - WARNING - Failed to get content for mailto:sohamg@uchicago.edu
# 2025-05-04 17:52:56,026 - INFO - Processing 147/1414: https://datascience.uchicago.edu/events/cdac-iot-lab-workshop
# 2025-05-04 17:52:57,106 - INFO - Saved ../data\markdown\events_cdac-iot-lab-workshop.md
# 2025-05-04 17:52:58,108 - INFO - Processing 148/1414: https://datascience.uchicago.edu/research/is-climate-change-changing-clouds
# 2025-05-04 17:52:59,080 - INFO - Saved ../data\markdown\research_is-climate-change-changing-clouds.md
# 2025-05-04 17:53:00,082 - INFO - Processing 149/1414: https://datascience.uchicago.edu/people/yj-choe
# 2025-05-04 17:53:01,119 - INFO - Saved ../data\markdown\people_yj-choe.md
# 2025-05-04 17:53:02,120 - INFO - Processing 150/1414: https://datascience.uchicago.edu/people/helen-michael
# 2025-05-04 17:53:03,107 - INFO - Saved ../data\markdown\people_helen-michael.md
# 2025-05-04 17:53:03,110 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:53:04,111 - INFO - Processing 151/1414: https://datascience.uchicago.edu/people/kate-keahey
# 2025-05-04 17:53:05,090 - INFO - Saved ../data\markdown\people_kate-keahey.md
# 2025-05-04 17:53:06,092 - INFO - Processing 152/1414: https://datascience.uchicago.edu/people/david-levi
# 2025-05-04 17:53:07,060 - INFO - Saved ../data\markdown\people_david-levi.md
# 2025-05-04 17:53:08,062 - INFO - Processing 153/1414: https://datascience.uchicago.edu/news/internet-disconnect
# 2025-05-04 17:53:08,995 - INFO - Saved ../data\markdown\news_internet-disconnect.md
# 2025-05-04 17:53:09,997 - INFO - Processing 154/1414: https://datascience.uchicago.edu/news/eric-and-wendy-schmidt-ai-in-science-postdoctoral-fellows-host-first-ever-hackathon
# 2025-05-04 17:53:11,023 - INFO - Saved ../data\markdown\news_eric-and-wendy-schmidt-ai-in-science-postdoctoral-fellows-host-first-ever-hackathon.md
# 2025-05-04 17:53:12,025 - INFO - Processing 155/1414: https://datascience.uchicago.edu/news/teaching-computers-perceptionwith-style
# 2025-05-04 17:53:13,016 - INFO - Saved ../data\markdown\news_teaching-computers-perceptionwith-style.md
# 2025-05-04 17:53:14,017 - INFO - Processing 156/1414: https://datascience.uchicago.edu/people/rana-hanocka
# 2025-05-04 17:53:14,974 - INFO - Saved ../data\markdown\people_rana-hanocka.md
# 2025-05-04 17:53:15,975 - INFO - Processing 157/1414: https://datascience.uchicago.edu/people/david-freedman
# 2025-05-04 17:53:16,894 - INFO - Saved ../data\markdown\people_david-freedman.md
# 2025-05-04 17:53:17,896 - INFO - Processing 158/1414: https://datascience.uchicago.edu/people/sainyam-galhotra
# 2025-05-04 17:53:18,889 - INFO - Saved ../data\markdown\people_sainyam-galhotra.md
# 2025-05-04 17:53:19,891 - INFO - Processing 159/1414: https://datascience.uchicago.edu/people/anthony-badea
# 2025-05-04 17:53:20,820 - INFO - Saved ../data\markdown\people_anthony-badea.md
# 2025-05-04 17:53:21,823 - INFO - Processing 160/1414: https://datascience.uchicago.edu/research/data-democracy
# 2025-05-04 17:53:22,816 - INFO - Saved ../data\markdown\research_data-democracy.md
# 2025-05-04 17:53:22,819 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:53:23,821 - INFO - Processing 161/1414: http://datascience.uchicago.edu/engage/data-science@uchicago.edu
# 2025-05-04 17:53:25,749 - ERROR - Error fetching http://datascience.uchicago.edu/engage/data-science@uchicago.edu: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/engage/data-science@uchicago.edu
# 2025-05-04 17:53:25,753 - WARNING - Failed to get content for http://datascience.uchicago.edu/engage/data-science@uchicago.edu
# 2025-05-04 17:53:25,755 - INFO - Processing 162/1414: https://datascience.uchicago.edu/people/ayah-ahmad
# 2025-05-04 17:53:26,699 - INFO - Saved ../data\markdown\people_ayah-ahmad.md
# 2025-05-04 17:53:27,701 - INFO - Processing 163/1414: https://datascience.uchicago.edu/people/johann-gaebler
# 2025-05-04 17:53:28,645 - INFO - Saved ../data\markdown\people_johann-gaebler.md
# 2025-05-04 17:53:29,646 - INFO - Processing 164/1414: https://datascience.uchicago.edu/insights/iot-inspector
# 2025-05-04 17:53:30,606 - INFO - Saved ../data\markdown\insights_iot-inspector.md
# 2025-05-04 17:53:31,608 - INFO - Processing 165/1414: https://datascience.uchicago.edu/internet-frontiers-and-opportunities-workshop
# 2025-05-04 17:53:32,811 - INFO - Saved ../data\markdown\internet-frontiers-and-opportunities-workshop.md
# 2025-05-04 17:53:33,813 - INFO - Processing 166/1414: https://datascience.uchicago.edu/news/the-world-awaits
# 2025-05-04 17:53:34,793 - INFO - Saved ../data\markdown\news_the-world-awaits.md
# 2025-05-04 17:53:35,794 - INFO - Processing 167/1414: https://datascience.uchicago.edu/events/tom-griffiths-princeton-distinguished-speaker-series
# 2025-05-04 17:53:36,709 - INFO - Saved ../data\markdown\events_tom-griffiths-princeton-distinguished-speaker-series.md
# 2025-05-04 17:53:37,711 - INFO - Processing 168/1414: https://datascience.uchicago.edu/news/data-driven-solutions-for-complex-social-issues-community-data-fellows-program
# 2025-05-04 17:53:38,820 - INFO - Saved ../data\markdown\news_data-driven-solutions-for-complex-social-issues-community-data-fellows-program.md
# 2025-05-04 17:53:39,822 - INFO - Processing 169/1414: https://datascience.uchicago.edu/people/stephania-tello-zamudio
# 2025-05-04 17:53:40,834 - INFO - Saved ../data\markdown\people_stephania-tello-zamudio.md
# 2025-05-04 17:53:41,836 - INFO - Processing 170/1414: http://datascience.uchicago.edu/news-events/news
# 2025-05-04 17:53:43,248 - INFO - Saved ../data\markdown\news-events_news.md
# 2025-05-04 17:53:43,250 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:53:44,251 - INFO - Processing 171/1414: https://datascience.uchicago.edu/events/brandon-stewart-princeton
# 2025-05-04 17:53:45,213 - INFO - Saved ../data\markdown\events_brandon-stewart-princeton.md
# 2025-05-04 17:53:46,216 - INFO - Processing 172/1414: https://datascience.uchicago.edu/news/ms-in-applied-data-science-shares-career-advice-with-stagg-high-school-students
# 2025-05-04 17:53:47,161 - INFO - Saved ../data\markdown\news_ms-in-applied-data-science-shares-career-advice-with-stagg-high-school-students.md
# 2025-05-04 17:53:48,163 - INFO - Processing 173/1414: https://datascience.uchicago.edu/events/maryam-fazel-washington-flat-minima
# 2025-05-04 17:53:49,146 - INFO - Saved ../data\markdown\events_maryam-fazel-washington-flat-minima.md
# 2025-05-04 17:53:50,148 - INFO - Processing 174/1414: https://datascience.uchicago.edu/news/masters-in-applied-data-science-autumn-2024-capstone-showcase
# 2025-05-04 17:53:51,130 - INFO - Saved ../data\markdown\news_masters-in-applied-data-science-autumn-2024-capstone-showcase.md
# 2025-05-04 17:53:52,131 - INFO - Processing 175/1414: https://datascience.uchicago.edu/research/neural-network-algorithms-to-decode-the-octopus-neural-network
# 2025-05-04 17:53:53,099 - INFO - Saved ../data\markdown\research_neural-network-algorithms-to-decode-the-octopus-neural-network.md
# 2025-05-04 17:53:54,101 - INFO - Processing 176/1414: https://datascience.uchicago.edu/events/michelle-ntampaka-space-telescope-science-institute-aiscience-schmidt-fellows-speaker-series
# 2025-05-04 17:53:55,136 - INFO - Saved ../data\markdown\events_michelle-ntampaka-space-telescope-science-institute-aiscience-schmidt-fellows-speaker-series.md
# 2025-05-04 17:53:56,140 - INFO - Processing 177/1414: https://datascience.uchicago.edu/news/using-ai-and-data-science-to-reliably-detect-internet-censorship-in-real-time
# 2025-05-04 17:53:57,081 - INFO - Saved ../data\markdown\news_using-ai-and-data-science-to-reliably-detect-internet-censorship-in-real-time.md
# 2025-05-04 17:53:58,083 - INFO - Processing 178/1414: https://datascience.uchicago.edu/education/internships/application
# 2025-05-04 17:53:59,029 - INFO - Saved ../data\markdown\education_internships_application.md
# 2025-05-04 17:54:00,031 - INFO - Processing 179/1414: https://datascience.uchicago.edu/people/xiaoan-ding
# 2025-05-04 17:54:00,934 - INFO - Saved ../data\markdown\people_xiaoan-ding.md
# 2025-05-04 17:54:01,936 - INFO - Processing 180/1414: https://datascience.uchicago.edu/news/new-mbio-data-portal-brings-transparency-to-genetically-modified-crops-in-africa
# 2025-05-04 17:54:02,885 - INFO - Saved ../data\markdown\news_new-mbio-data-portal-brings-transparency-to-genetically-modified-crops-in-africa.md
# 2025-05-04 17:54:02,890 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:54:03,892 - INFO - Processing 181/1414: https://datascience.uchicago.edu/people/xi-cheng
# 2025-05-04 17:54:04,888 - INFO - Saved ../data\markdown\people_xi-cheng.md
# 2025-05-04 17:54:05,890 - INFO - Processing 182/1414: https://datascience.uchicago.edu/people/sam-zhang
# 2025-05-04 17:54:06,830 - INFO - Saved ../data\markdown\people_sam-zhang.md
# 2025-05-04 17:54:07,831 - INFO - Processing 183/1414: https://datascience.uchicago.edu/news/the-university-of-chicago-data-science-institute-and-google-partner-on-cutting-edge-ai-and-security-research
# 2025-05-04 17:54:08,960 - INFO - Saved ../data\markdown\news_the-university-of-chicago-data-science-institute-and-google-partner-on-cutting-edge-ai-and-security-research.md
# 2025-05-04 17:54:09,961 - INFO - Processing 184/1414: https://datascience.uchicago.edu/outreach/data4all/apply
# 2025-05-04 17:54:10,888 - INFO - Saved ../data\markdown\outreach_data4all_apply.md
# 2025-05-04 17:54:11,890 - INFO - Processing 185/1414: https://datascience.uchicago.edu/education/summerlab/2019-cohort
# 2025-05-04 17:54:12,956 - INFO - Saved ../data\markdown\education_summerlab_2019-cohort.md
# 2025-05-04 17:54:13,958 - INFO - Processing 186/1414: https://datascience.uchicago.edu/news/chicago-data-nights-bring-together-academics-and-industry-professionals-in-downtown-chicago
# 2025-05-04 17:54:14,918 - INFO - Saved ../data\markdown\news_chicago-data-nights-bring-together-academics-and-industry-professionals-in-downtown-chicago.md
# 2025-05-04 17:54:15,919 - INFO - Processing 187/1414: https://datascience.uchicago.edu/events/inderjit-dhillon-uta
# 2025-05-04 17:54:16,879 - INFO - Saved ../data\markdown\events_inderjit-dhillon-uta.md
# 2025-05-04 17:54:17,881 - INFO - Processing 188/1414: https://datascience.uchicago.edu/research/mapping-and-mitigating-the-urban-digital-divide
# 2025-05-04 17:54:19,341 - ERROR - Error fetching https://datascience.uchicago.edu/research/mapping-and-mitigating-the-urban-digital-divide: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/research/mapping-and-mitigating-the-urban-digital-divide
# 2025-05-04 17:54:19,345 - WARNING - Failed to get content for https://datascience.uchicago.edu/research/mapping-and-mitigating-the-urban-digital-divide
# 2025-05-04 17:54:19,347 - INFO - Processing 189/1414: https://datascience.uchicago.edu/people/alex-tuecke
# 2025-05-04 17:54:20,294 - INFO - Saved ../data\markdown\people_alex-tuecke.md
# 2025-05-04 17:54:21,296 - INFO - Processing 190/1414: https://datascience.uchicago.edu/research/ai-science
# 2025-05-04 17:54:22,342 - INFO - Saved ../data\markdown\research_ai-science.md
# 2025-05-04 17:54:22,346 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 17:54:23,348 - INFO - Processing 191/1414: https://datascience.uchicago.edu/people/dylan-halpern
# 2025-05-04 17:54:24,337 - INFO - Saved ../data\markdown\people_dylan-halpern.md
# ...
# 2025-05-04 18:32:14,052 - WARNING - Failed to get content for mailto:kmccann6@uchicago.edu
# 2025-05-04 18:32:14,054 - INFO - Processing 1354/1414: https://datascience.uchicago.edu/people/nathalie-valenzuela
# 2025-05-04 18:32:14,990 - INFO - Saved ../data\markdown\people_nathalie-valenzuela.md
# 2025-05-04 18:32:15,991 - INFO - Processing 1355/1414: https://datascience.uchicago.edu/news/aiscience-conference-hosted-by-uchicago-caltech-gathers-top-experts
# 2025-05-04 18:32:16,995 - INFO - Saved ../data\markdown\news_aiscience-conference-hosted-by-uchicago-caltech-gathers-top-experts.md
# 2025-05-04 18:32:17,997 - INFO - Processing 1356/1414: https://hsdatasciencestudy.datascience.uchicago.edu/curriculum/bootstrap-data-science
# 2025-05-04 18:32:18,974 - INFO - Saved ../data\markdown\curriculum_bootstrap-data-science.md
# 2025-05-04 18:32:19,976 - INFO - Processing 1357/1414: https://datascience.uchicago.edu/insights/light-reading-podcast-nick-feamster-on-covid-19-and-network-needs
# 2025-05-04 18:32:20,943 - INFO - Saved ../data\markdown\insights_light-reading-podcast-nick-feamster-on-covid-19-and-network-needs.md
# 2025-05-04 18:32:21,945 - INFO - Processing 1358/1414: https://datascience.uchicago.edu/events/introducing-palmwatch-mapping-the-impact-of-big-brands-palm-oil-use
# 2025-05-04 18:32:22,884 - INFO - Saved ../data\markdown\events_introducing-palmwatch-mapping-the-impact-of-big-brands-palm-oil-use.md
# 2025-05-04 18:32:23,886 - INFO - Processing 1359/1414: https://datascience.uchicago.edu/people/yuzhe-yang
# 2025-05-04 18:32:24,830 - INFO - Saved ../data\markdown\people_yuzhe-yang.md
# 2025-05-04 18:32:25,831 - INFO - Processing 1360/1414: https://datascience.uchicago.edu/people/alexis-schrubbe
# 2025-05-04 18:32:26,797 - INFO - Saved ../data\markdown\people_alexis-schrubbe.md
# 2025-05-04 18:32:26,802 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 18:32:27,803 - INFO - Processing 1361/1414: https://datascience.uchicago.edu/people/jim-pivarski
# 2025-05-04 18:32:28,806 - INFO - Saved ../data\markdown\people_jim-pivarski.md
# 2025-05-04 18:32:29,808 - INFO - Processing 1362/1414: https://datascience.uchicago.edu/people/noah-golowich
# 2025-05-04 18:32:30,803 - INFO - Saved ../data\markdown\people_noah-golowich.md
# 2025-05-04 18:32:31,805 - INFO - Processing 1363/1414: https://datascience.uchicago.edu/research/internet-access-equity-initiative
# 2025-05-04 18:32:33,277 - ERROR - Error fetching https://datascience.uchicago.edu/research/internet-access-equity-initiative: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/research/internet-access-equity-initiative
# 2025-05-04 18:32:33,279 - WARNING - Failed to get content for https://datascience.uchicago.edu/research/internet-access-equity-initiative
# 2025-05-04 18:32:33,280 - INFO - Processing 1364/1414: https://datascience.uchicago.edu/events/cdac-summer-lab-broadbandproject
# 2025-05-04 18:32:34,208 - INFO - Saved ../data\markdown\events_cdac-summer-lab-broadbandproject.md
# 2025-05-04 18:32:35,210 - INFO - Processing 1365/1414: https://datascience.uchicago.edu/news/aiscience-conference-receives-funding-to-expand-across-the-next-three-years
# 2025-05-04 18:32:36,254 - INFO - Saved ../data\markdown\news_aiscience-conference-receives-funding-to-expand-across-the-next-three-years.md
# 2025-05-04 18:32:37,255 - INFO - Processing 1366/1414: https://datascience.uchicago.edu/events/ioana-ciuca-stanford-ai-science-schmidt-fellows-speaker-series
# 2025-05-04 18:32:38,267 - INFO - Saved ../data\markdown\events_ioana-ciuca-stanford-ai-science-schmidt-fellows-speaker-series.md
# 2025-05-04 18:32:39,268 - INFO - Processing 1367/1414: https://datascience.uchicago.edu/news/outlier-research-evaluation-joins-dsi-deepening-focus-on-pk-16-data-science-education-research
# 2025-05-04 18:32:40,323 - INFO - Saved ../data\markdown\news_outlier-research-evaluation-joins-dsi-deepening-focus-on-pk-16-data-science-education-research.md
# 2025-05-04 18:32:41,325 - INFO - Processing 1368/1414: mailto:dusmith@uchicago.edu
# 2025-05-04 18:32:41,327 - ERROR - Error fetching mailto:dusmith@uchicago.edu: No connection adapters were found for 'mailto:dusmith@uchicago.edu'
# 2025-05-04 18:32:41,328 - WARNING - Failed to get content for mailto:dusmith@uchicago.edu
# 2025-05-04 18:32:41,330 - INFO - Processing 1369/1414: https://datascience.uchicago.edu/fellows-and-scholars
# 2025-05-04 18:32:42,367 - INFO - Saved ../data\markdown\fellows-and-scholars.md
# 2025-05-04 18:32:43,368 - INFO - Processing 1370/1414: https://datascience.uchicago.edu/insights/whats-on-your-internet-performance-dashboard
# 2025-05-04 18:32:44,370 - INFO - Saved ../data\markdown\insights_whats-on-your-internet-performance-dashboard.md
# 2025-05-04 18:32:44,376 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 18:32:45,377 - INFO - Processing 1371/1414: https://datascience.uchicago.edu/research/postdoctoral-programs/data-science@uchicago.edu
# 2025-05-04 18:32:46,818 - ERROR - Error fetching https://datascience.uchicago.edu/research/postdoctoral-programs/data-science@uchicago.edu: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/research/postdoctoral-programs/data-science@uchicago.edu
# 2025-05-04 18:32:46,820 - WARNING - Failed to get content for https://datascience.uchicago.edu/research/postdoctoral-programs/data-science@uchicago.edu
# 2025-05-04 18:32:46,821 - INFO - Processing 1372/1414: https://datascience.uchicago.edu/people/joshua-frieman
# 2025-05-04 18:32:47,810 - INFO - Saved ../data\markdown\people_joshua-frieman.md
# 2025-05-04 18:32:48,812 - INFO - Processing 1373/1414: https://datascience.uchicago.edu/people/april-wang
# 2025-05-04 18:32:49,778 - INFO - Saved ../data\markdown\people_april-wang.md
# 2025-05-04 18:32:50,779 - INFO - Processing 1374/1414: https://datascience.uchicago.edu/people/hridoy-sankar-dutta
# 2025-05-04 18:32:51,714 - INFO - Saved ../data\markdown\people_hridoy-sankar-dutta.md
# 2025-05-04 18:32:52,716 - INFO - Processing 1375/1414: https://datascience.uchicago.edu/people/taylor-wallace
# 2025-05-04 18:32:53,720 - INFO - Saved ../data\markdown\people_taylor-wallace.md
# 2025-05-04 18:32:54,722 - INFO - Processing 1376/1414: https://datascience.uchicago.edu/about/affiliated-scholars
# 2025-05-04 18:32:56,078 - INFO - Saved ../data\markdown\about_affiliated-scholars.md
# 2025-05-04 18:32:57,080 - INFO - Processing 1377/1414: https://datascience.uchicago.edu/news/transform-cohort-3-participant-healee-uses-ai-to-improve-healthcare
# 2025-05-04 18:32:58,075 - INFO - Saved ../data\markdown\news_transform-cohort-3-participant-healee-uses-ai-to-improve-healthcare.md
# 2025-05-04 18:32:59,077 - INFO - Processing 1378/1414: https://datascience.uchicago.edu/news/rina-foygel-barber-and-margaret-gardel-elected-to-the-national-academy-of-sciences
# 2025-05-04 18:33:00,052 - INFO - Saved ../data\markdown\news_rina-foygel-barber-and-margaret-gardel-elected-to-the-national-academy-of-sciences.md
# 2025-05-04 18:33:01,053 - INFO - Processing 1379/1414: https://datascience.uchicago.edu/people/ashwin-aggarwal
# 2025-05-04 18:33:02,044 - INFO - Saved ../data\markdown\people_ashwin-aggarwal.md
# 2025-05-04 18:33:03,046 - INFO - Processing 1380/1414: mailto:ssegovba@uchicago.edu
# 2025-05-04 18:33:03,047 - ERROR - Error fetching mailto:ssegovba@uchicago.edu: No connection adapters were found for 'mailto:ssegovba@uchicago.edu'
# 2025-05-04 18:33:03,049 - WARNING - Failed to get content for mailto:ssegovba@uchicago.edu
# 2025-05-04 18:33:03,051 - INFO - Processing 1381/1414: https://hsdatasciencestudy.datascience.uchicago.edu
# 2025-05-04 18:33:04,043 - INFO - Saved ../data\markdown\index.md
# 2025-05-04 18:33:05,045 - INFO - Processing 1382/1414: https://datascience.uchicago.edu/people/morgan-anderson
# 2025-05-04 18:33:05,959 - INFO - Saved ../data\markdown\people_morgan-anderson.md
# 2025-05-04 18:33:06,961 - INFO - Processing 1383/1414: https://datascience.uchicago.edu/news/masters-in-applied-data-science-winter-2024-capstone-winners
# 2025-05-04 18:33:07,922 - INFO - Saved ../data\markdown\news_masters-in-applied-data-science-winter-2024-capstone-winners.md
# 2025-05-04 18:33:08,923 - INFO - Processing 1384/1414: https://datascience.uchicago.edu/people/harry-wu
# 2025-05-04 18:33:10,004 - INFO - Saved ../data\markdown\people_harry-wu.md
# 2025-05-04 18:33:11,006 - INFO - Processing 1385/1414: https://datascience.uchicago.edu/news/uchicago-undergrad-analyzes-machine-learning-models-used-by-cpd-uncovers-lack-of-transparency-about-data-usage
# 2025-05-04 18:33:12,005 - INFO - Saved ../data\markdown\news_uchicago-undergrad-analyzes-machine-learning-models-used-by-cpd-uncovers-lack-of-transparency-about-data-usage.md
# 2025-05-04 18:33:13,006 - INFO - Processing 1386/1414: https://datascience.uchicago.edu/events/risingstars2021
# 2025-05-04 18:33:14,026 - INFO - Saved ../data\markdown\events_risingstars2021.md
# 2025-05-04 18:33:15,029 - INFO - Processing 1387/1414: https://datascience.uchicago.edu/people/esha-mujumdar
# 2025-05-04 18:33:16,001 - INFO - Saved ../data\markdown\people_esha-mujumdar.md
# 2025-05-04 18:33:17,002 - INFO - Processing 1388/1414: https://datascience.uchicago.edu/research/understanding-divergent-interpretations-of-political-information
# 2025-05-04 18:33:18,019 - INFO - Saved ../data\markdown\research_understanding-divergent-interpretations-of-political-information.md
# 2025-05-04 18:33:19,021 - INFO - Processing 1389/1414: https://datascience.uchicago.edu/research/postdoctoral-programs/rising-stars/2021
# 2025-05-04 18:33:20,352 - INFO - Saved ../data\markdown\research_postdoctoral-programs_rising-stars_2021.md
# 2025-05-04 18:33:21,354 - INFO - Processing 1390/1414: https://datascience.uchicago.edu/events/rising-stars-in-data-science-workshop-autumn-2023
# 2025-05-04 18:33:22,424 - INFO - Saved ../data\markdown\events_rising-stars-in-data-science-workshop-autumn-2023.md
# 2025-05-04 18:33:22,428 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 18:33:23,429 - INFO - Processing 1391/1414: mailto:emkerr@uchicago.edu
# 2025-05-04 18:33:23,434 - ERROR - Error fetching mailto:emkerr@uchicago.edu: No connection adapters were found for 'mailto:emkerr@uchicago.edu'
# 2025-05-04 18:33:23,435 - WARNING - Failed to get content for mailto:emkerr@uchicago.edu
# 2025-05-04 18:33:23,437 - INFO - Processing 1392/1414: https://datascience.uchicago.edu/people/briana-allen
# 2025-05-04 18:33:24,409 - INFO - Saved ../data\markdown\people_briana-allen.md
# 2025-05-04 18:33:25,411 - INFO - Processing 1393/1414: https://datascience.uchicago.edu/people/avery-schwartz
# 2025-05-04 18:33:26,345 - INFO - Saved ../data\markdown\people_avery-schwartz.md
# 2025-05-04 18:33:27,347 - INFO - Processing 1394/1414: https://datascience.uchicago.edu/people/alexandra-nisenoff
# 2025-05-04 18:33:28,291 - INFO - Saved ../data\markdown\people_alexandra-nisenoff.md
# 2025-05-04 18:33:29,292 - INFO - Processing 1395/1414: https://datascience.uchicago.edu/people/grace-su
# 2025-05-04 18:33:30,307 - INFO - Saved ../data\markdown\people_grace-su.md
# 2025-05-04 18:33:31,308 - INFO - Processing 1396/1414: https://datascience.uchicago.edu/news/uchicago-ai-summit-examines-promise-and-concerns-for-science-and-society
# 2025-05-04 18:33:32,325 - INFO - Saved ../data\markdown\news_uchicago-ai-summit-examines-promise-and-concerns-for-science-and-society.md
# 2025-05-04 18:33:33,326 - INFO - Processing 1397/1414: https://datascience.uchicago.edu/people/zhijian-liu
# 2025-05-04 18:33:34,339 - INFO - Saved ../data\markdown\people_zhijian-liu.md
# 2025-05-04 18:33:35,340 - INFO - Processing 1398/1414: https://datascience.uchicago.edu/research/ai-science/partnerships/pritzker-aiscience-joint-initiative-with-caltech
# 2025-05-04 18:33:36,359 - INFO - Saved ../data\markdown\research_ai-science_partnerships_pritzker-aiscience-joint-initiative-with-caltech.md
# 2025-05-04 18:33:37,361 - INFO - Processing 1399/1414: https://datascience.uchicago.edu/people/edona-saliu
# 2025-05-04 18:33:38,356 - INFO - Saved ../data\markdown\people_edona-saliu.md
# 2025-05-04 18:33:39,358 - INFO - Processing 1400/1414: https://datascience.uchicago.edu/people/risi-kondor
# 2025-05-04 18:33:40,290 - INFO - Saved ../data\markdown\people_risi-kondor.md
# 2025-05-04 18:33:40,296 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 18:33:41,297 - INFO - Processing 1401/1414: https://datascience.uchicago.edu/people/joshua-conrad-jackson
# 2025-05-04 18:33:42,221 - INFO - Saved ../data\markdown\people_joshua-conrad-jackson.md
# 2025-05-04 18:33:43,222 - INFO - Processing 1402/1414: https://datascience.uchicago.edu/insights/the-case-for-component-based-research-in-education
# 2025-05-04 18:33:44,152 - INFO - Saved ../data\markdown\insights_the-case-for-component-based-research-in-education.md
# 2025-05-04 18:33:45,153 - INFO - Processing 1403/1414: https://datascience.uchicago.edu/people/jennifer-sun
# 2025-05-04 18:33:46,118 - INFO - Saved ../data\markdown\people_jennifer-sun.md
# 2025-05-04 18:33:47,119 - INFO - Processing 1404/1414: https://datascience.uchicago.edu/research/research-funding/ai-science-research-funding-opportunities
# 2025-05-04 18:33:48,126 - INFO - Saved ../data\markdown\research_research-funding_ai-science-research-funding-opportunities.md
# 2025-05-04 18:33:49,128 - INFO - Processing 1405/1414: https://datascience.uchicago.edu/ai-science-summer-school-2023-friday
# 2025-05-04 18:33:50,092 - INFO - Saved ../data\markdown\ai-science-summer-school-2023-friday.md
# 2025-05-04 18:33:51,094 - INFO - Processing 1406/1414: https://datascience.uchicago.edu/people/konstantin-mishchenko
# 2025-05-04 18:33:52,039 - INFO - Saved ../data\markdown\people_konstantin-mishchenko.md
# 2025-05-04 18:33:53,041 - INFO - Processing 1407/1414: https://datascience.uchicago.edu/insights/modeling-chaos-using-machine-learning-emulators
# 2025-05-04 18:33:54,028 - INFO - Saved ../data\markdown\insights_modeling-chaos-using-machine-learning-emulators.md
# 2025-05-04 18:33:55,029 - INFO - Processing 1408/1414: https://datascience.uchicago.edu/people/joshua-athayde
# 2025-05-04 18:33:56,008 - INFO - Saved ../data\markdown\people_joshua-athayde.md
# 2025-05-04 18:33:57,011 - INFO - Processing 1409/1414: https://datascience.uchicago.edu/people/omar-montasser
# 2025-05-04 18:33:57,946 - INFO - Saved ../data\markdown\people_omar-montasser.md
# 2025-05-04 18:33:58,948 - INFO - Processing 1410/1414: https://datascience.uchicago.edu/people/zihan-jack-zhang
# 2025-05-04 18:33:59,931 - INFO - Saved ../data\markdown\people_zihan-jack-zhang.md
# 2025-05-04 18:33:59,936 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 18:34:00,937 - INFO - Processing 1411/1414: https://datascience.uchicago.edu/events/milind-tambe-harvard-ai-for-social-impact
# 2025-05-04 18:34:01,917 - INFO - Saved ../data\markdown\events_milind-tambe-harvard-ai-for-social-impact.md
# 2025-05-04 18:34:02,919 - INFO - Processing 1412/1414: mailto:tmangla@uchicago.edu
# 2025-05-04 18:34:02,921 - ERROR - Error fetching mailto:tmangla@uchicago.edu: No connection adapters were found for 'mailto:tmangla@uchicago.edu'
# 2025-05-04 18:34:02,923 - WARNING - Failed to get content for mailto:tmangla@uchicago.edu
# 2025-05-04 18:34:02,924 - INFO - Processing 1413/1414: https://datascience.uchicago.edu/insights/expanding-our-vocabulary-of-vision-using-ai
# 2025-05-04 18:34:03,873 - INFO - Saved ../data\markdown\insights_expanding-our-vocabulary-of-vision-using-ai.md
# 2025-05-04 18:34:04,874 - INFO - Processing 1414/1414: https://datascience.uchicago.edu/news/pit-un-grant-supports-dsi-community-data-fellows-program
# 2025-05-04 18:34:05,866 - INFO - Saved ../data\markdown\news_pit-un-grant-supports-dsi-community-data-fellows-program.md
# 2025-05-04 18:34:06,875 - INFO - Saved processing status to ../data\processed_links.json
# 2025-05-04 18:34:06,877 - INFO - Content processing completed in 2749.39 seconds
# 2025-05-04 18:34:06,879 - INFO - Processed: 1246 pages
# 2025-05-04 18:34:06,880 - INFO - Failed: 168 pages

# %%
# Create a summary of the processed pages by category
if os.path.exists(PROCESSED_FILE):
    with open(PROCESSED_FILE, 'r') as f:
        processed_data = json.load(f)
    
    # Get all markdown files
    markdown_files = os.listdir(MARKDOWN_DIR)
    
    # Extract categories from frontmatter
    categories = {}
    for md_file in markdown_files:
        if md_file.endswith('.md'):
            filepath = os.path.join(MARKDOWN_DIR, md_file)
            with open(filepath, 'r', encoding='utf-8') as f:
                content = f.read()
                match = re.search(r'category:\s*([^\n]+)', content)
                if match:
                    category = match.group(1).strip()
                    categories[category] = categories.get(category, 0) + 1
    
    # Create a DataFrame
    category_df = pd.DataFrame({
        'Category': list(categories.keys()),
        'Count': list(categories.values())
    }).sort_values('Count', ascending=False)
    
    display(category_df)
    
    # Save summary to CSV
    summary_path = os.path.join(DATA_DIR, 'category_summary.csv')
    category_df.to_csv(summary_path, index=False)
    print(f"\nCategory summary saved to {summary_path}")
# Out:
#                                              Category  Count
# 30                                             people    637
# 27                                               news    177
# 17                                             events    165
# 33                                           research     84
# 22                                           insights     60
# 15                                          education     33
# 29                                           outreach     28
# 2                                               about      8
# 16                                             engage      6
# 13                                         curriculum      4
# 25                                        news-events      3
# 31                                              pilot      2
# 3                ai-science-summer-school-2023-friday      1
# 1                                            about-us      1
# 0                                   11th-hour-project      1
# 4                ai-science-summer-school-2023-monday      1
# 7             ai-science-summer-school-2023-wednesday      1
# 6               ai-science-summer-school-2023-tuesday      1
# 5              ai-science-summer-school-2023-thursday      1
# 12                               curriculum-overviews      1
# 14                                data-science-clinic      1
# 11                                   classroom-voices      1
# 8                                aiscience-conference      1
# 9                                         at-a-glance      1
# 23      internet-frontiers-and-opportunities-workshop      1
# 21                                           homepage      1
# 20                                       how-to-apply      1
# 19                               fellows-and-scholars      1
# 18                          explore-the-ms-ads-campus      1
# 10                                  capstone-projects      1
# 26                                 newsletter-archive      1
# 24                                            iot-lab      1
# 28                        nondiscrimination-statement      1
# 32                          postdocprograminfosession      1
# 34                                       rising-stars      1
# 35                                     student-voices      1
# 36                                     teacher-voices      1
# 37                           test-course-progressions      1
# 38  the-university-of-chicago-and-caltech-conferen...      1
# 39                                         wp-content      1
# Category summary saved to ../data\category_summary.csv

# %%
# Analysis of the content (word count, etc.)
def count_words_in_file(filepath):
    """
    Count the number of words in a markdown file (excluding frontmatter)
    """
    with open(filepath, 'r', encoding='utf-8') as f:
        content = f.read()
        
    # Remove frontmatter
    content = re.sub(r'^---\n.*?\n---\n', '', content, flags=re.DOTALL)
    
    # Count words
    words = re.findall(r'\w+', content)
    return len(words)

# %%
# Calculate word counts for each file
markdown_files = [f for f in os.listdir(MARKDOWN_DIR) if f.endswith('.md')]
word_counts = []

for md_file in markdown_files:
    filepath = os.path.join(MARKDOWN_DIR, md_file)
    count = count_words_in_file(filepath)
    
    # Extract URL and title from frontmatter
    with open(filepath, 'r', encoding='utf-8') as f:
        content = f.read()
        url_match = re.search(r'original_url:\s*([^\n]+)', content)
        title_match = re.search(r'title:\s*([^\n]+)', content)
        category_match = re.search(r'category:\s*([^\n]+)', content)
        
        url = url_match.group(1).strip() if url_match else ""
        title = title_match.group(1).strip() if title_match else ""
        category = category_match.group(1).strip() if category_match else ""
    
    word_counts.append({
        'Filename': md_file,
        'Title': title,
        'URL': url,
        'Category': category,
        'Word Count': count
    })

word_count_df = pd.DataFrame(word_counts)
word_count_df = word_count_df.sort_values('Word Count', ascending=False)

# Show top 10 pages by word count
print("Top 10 pages by word count:")
display(word_count_df.head(10))

# Save word count data
word_count_path = os.path.join(DATA_DIR, 'word_count_summary.csv')
word_count_df.to_csv(word_count_path, index=False)
print(f"\nWord count summary saved to {word_count_path}")
# Out:
# Top 10 pages by word count:
#                                                Filename  \
# 1213  research_postdoctoral-programs_rising-stars_20...
# 1229                                    rising-stars.md
# 1211  research_postdoctoral-programs_rising-stars-in...
# 1214  research_postdoctoral-programs_rising-stars_20...
# 41    education_masters-programs_ms-in-applied-data-...
# 1                                           about-us.md
# 1233  the-university-of-chicago-and-caltech-conferen...
# 50                   education_summerlab_2020-cohort.md
# 72              events_ai-science-summer-school-2024.md
# 51                   education_summerlab_2021-cohort.md
#
#                                                   Title  \
# 1213                            2021 Rising Stars – DSI
# 1229                            2021 Rising Stars – DSI
# 1211                            2023 Rising Stars – DSI
# 1214                            2022 Rising Stars – DSI
# 41                    Faculty, Instructors, Staff – DSI
# 1                     Faculty, Instructors, Staff – DSI
# 1233  The University of Chicago and Caltech Conferen...
# 50                          2020 Project Profiles – DSI
# 72                  AI+Science Summer School 2024 – DSI
# 51                          2021 Project Profiles – DSI
#
#                                                     URL  \
# 1213  https://datascience.uchicago.edu/research/post...
# 1229      https://datascience.uchicago.edu/rising-stars
# 1211  https://datascience.uchicago.edu/research/post...
# 1214  https://datascience.uchicago.edu/research/post...
# 41    https://datascience.uchicago.edu/education/mas...
# 1             https://datascience.uchicago.edu/about-us
# 1233  https://datascience.uchicago.edu/the-universit...
# 50    https://datascience.uchicago.edu/education/sum...
# 72    https://datascience.uchicago.edu/events/ai-sci...
# 51    https://datascience.uchicago.edu/education/sum...
#
#                                                Category  Word Count
# 1213                                           research       21991
# 1229                                       rising-stars       21991
# 1211                                           research       11908
# 1214                                           research       11371
# 41                                            education        9993
# 1                                              about-us        9993
# 1233  the-university-of-chicago-and-caltech-conferen...        8723
# 50                                            education        6901
# 72                                               events        6607
# 51                                            education        5727
# Word count summary saved to ../data\word_count_summary.csv
