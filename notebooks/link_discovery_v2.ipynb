# %% [markdown]
# # UChicago MS in Applied Data Science Website - Link Discovery
#
# This notebook handles Phase 1 of the scraping process: discovering all links on the UChicago Data Science Institute website and saving them for later processing.

# %%
import os
import json
import requests
from urllib.parse import urljoin, urlparse, urlunparse
import time
import logging
from datetime import datetime
from robotexclusionrulesparser import RobotExclusionRulesParser
from pathlib import Path # For more robust path handling
from bs4 import BeautifulSoup

# %%
BASE_URL = "https://datascience.uchicago.edu/"
# Start URL for discovery
START_URL = "https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/"
# Output directory for data files
OUTPUT_DIR = "../data"
# Output directory for log files
LOGS_DIR = "../logs"
# Delay between requests to be polite to the server (in seconds)
REQUEST_DELAY = 0.1  # Adjusted for politeness and performance
# Timeout for requests (in seconds)
REQUEST_TIMEOUT = 15
# File to save discovered links
LINKS_FILE = os.path.join(OUTPUT_DIR, "discovered_links.json")
# User-Agent for requests
USER_AGENT = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0.0.0 Safari/537.36 GenAICodeReviewBot/1.0'
# List of file extensions to ignore during link discovery
EXCLUDED_FILE_EXTENSIONS = ('.pdf', '.jpg', '.jpeg', '.png', '.gif', '.zip', '.doc', '.docx', '.xls', '.xlsx', '.ppt', '.pptx', '.mp3', '.mp4', '.avi', '.mov', '.webp', '.svg')
# Schemes to ignore
EXCLUDED_SCHEMES = ('mailto', 'tel', 'javascript')

# %%
Path(OUTPUT_DIR).mkdir(parents=True, exist_ok=True)
Path(LOGS_DIR).mkdir(parents=True, exist_ok=True)

# %%
log_file = Path(LOGS_DIR) / f"link_discovery_{datetime.now().strftime('%Y%m%d_%H%M%S')}.log"
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(module)s - %(funcName)s - %(message)s',
    handlers=[
        logging.FileHandler(log_file, encoding='utf-8'),
        logging.StreamHandler()  # Also log to console
    ]
)
logger = logging.getLogger(__name__)

# %%
session = requests.Session()
session.headers.update({'User-Agent': USER_AGENT})

# %%
robots_parser = RobotExclusionRulesParser()
try:
    robots_url = urljoin(BASE_URL, "robots.txt")
    robots_response = session.get(robots_url, timeout=REQUEST_TIMEOUT)
    robots_response.raise_for_status()
    robots_parser.parse(robots_response.text)
    logger.info(f"Successfully fetched and parsed robots.txt from {robots_url}")
except requests.RequestException as e:
    logger.warning(f"Could not fetch robots.txt from {robots_url}: {e}. Proceeding without robots.txt rules.")
except Exception as e:
    logger.warning(f"Error parsing robots.txt: {e}. Proceeding without robots.txt rules.")
# Out:
# 2025-05-12 10:59:45,468 - INFO - 2998126080 - <module> - Successfully fetched and parsed robots.txt from https://datascience.uchicago.edu/robots.txt

# %%
def is_allowed_by_robots(url):
    """Check if a URL is allowed by robots.txt."""
    if robots_parser: # Check if parser was initialized
        return robots_parser.is_allowed(USER_AGENT, url)
    return True # Default to allowed if robots.txt could not be parsed

# %%
def is_relevant_link(url, base_domain):
    """
    Check if a URL is internal to the specified base_domain, not a file,
    and not an excluded scheme.
    """
    parsed_url = urlparse(url)
    
    # Check scheme
    if parsed_url.scheme in EXCLUDED_SCHEMES:
        logger.debug(f"Skipping URL with excluded scheme: {url}")
        return False
        
    # Check if it's an HTTP/HTTPS URL
    if parsed_url.scheme not in ('http', 'https'):
        logger.debug(f"Skipping non-HTTP/HTTPS URL: {url}")
        return False

    # Check domain
    if not parsed_url.netloc or base_domain not in parsed_url.netloc:
        logger.debug(f"Skipping external URL: {url}")
        return False
        
    # Check file extension
    path = parsed_url.path
    if any(path.lower().endswith(ext) for ext in EXCLUDED_FILE_EXTENSIONS):
        logger.debug(f"Skipping URL with excluded file extension: {url}")
        return False
        
    return True

# %%
def normalize_url(url):
    """
    Normalize URL by removing trailing slashes, fragments, and common tracking query parameters.
    Keeps scheme and netloc case-insensitive as per RFC 3986.
    """
    parsed = urlparse(url)
    # Normalize scheme and netloc to lowercase
    normalized_scheme = parsed.scheme.lower()
    normalized_netloc = parsed.netloc.lower()
    
    # Reconstruct URL without fragment and query parameters (can be made more selective if needed)
    # For this specific site, removing all query params seems fine, but for others, you might want to be selective.
    normalized_path = parsed.path.rstrip('/') if parsed.path else ''
    if not normalized_path and (parsed.query or parsed.fragment): # if it was just "domain.com/"
        normalized_path = '/'

    # Ensure path starts with '/' if netloc is present
    if normalized_netloc and not normalized_path.startswith('/') and normalized_path:
        normalized_path = '/' + normalized_path
    elif not normalized_path and normalized_netloc: # Handle base URL like https://domain.com
        normalized_path = '/'


    # Reconstruct without fragment and query
    # For more general scraping, one might want to selectively keep some query parameters.
    # For this project, removing them simplifies duplicate detection.
    reconstructed_url = urlunparse((normalized_scheme, normalized_netloc, normalized_path, '', '', ''))
    
    return reconstructed_url

# %%
def get_page_content_and_type(url):
    """
    Fetch the content and content type of a page.
    Returns (content_text, content_type_main) or (None, None) on error.
    """
    try:
        response = session.get(url, timeout=REQUEST_TIMEOUT)
        response.raise_for_status()  # Raise HTTPError for bad responses (4XX or 5XX)
        content_type = response.headers.get('Content-Type', '').lower()
        content_type_main = content_type.split(';')[0]
        logger.debug(f"Fetched {url} with Content-Type: {content_type}")
        return response.text, content_type_main
    except requests.exceptions.Timeout:
        logger.error(f"Timeout while fetching {url}")
    except requests.exceptions.HTTPError as e:
        logger.error(f"HTTP error fetching {url}: {e}")
    except requests.exceptions.RequestException as e:
        logger.error(f"Error fetching {url}: {e}")
    except Exception as e: # Catch any other unexpected errors
        logger.error(f"Unexpected error fetching {url}: {e}", exc_info=True)
    return None, None

# %%
def extract_links_from_html(html_content, current_url, base_domain):
    """
    Extract and filter relevant links from HTML content.
    """
    soup = BeautifulSoup(html_content, 'html.parser')
    extracted_links = set() # Use a set to store unique links from this page

    for a_tag in soup.find_all('a', href=True):
        href = a_tag['href']
        
        if not href or href.startswith('#'): # Skip empty or fragment-only links
            logger.debug(f"Skipping empty or fragment link: {href}")
            continue
            
        full_url = urljoin(current_url, href)
        normalized_full_url = normalize_url(full_url)
        
        if is_relevant_link(normalized_full_url, base_domain) and is_allowed_by_robots(normalized_full_url):
            extracted_links.add(normalized_full_url)
        else:
            logger.debug(f"Skipping irrelevant or disallowed link: {normalized_full_url}")
            
    return list(extracted_links)

# %%
def discover_all_urls(start_url):
    """
    Discover all relevant and allowed URLs on the website starting from start_url.
    """
    base_domain = urlparse(start_url).netloc
    queue = [normalize_url(start_url)]
    discovered_urls = set(queue) # Initialize with the start URL
    processed_urls_count = 0

    logger.info(f"Starting URL discovery from: {start_url} (Domain: {base_domain})")

    while queue:
        current_url = queue.pop(0)
        processed_urls_count += 1
        logger.info(f"Processing {processed_urls_count}/{len(discovered_urls) + len(queue)}: {current_url}")

        html_content, content_type = get_page_content_and_type(current_url)

        if not html_content:
            logger.warning(f"No content fetched for {current_url}. Skipping link extraction.")
            continue
        
        if 'text/html' not in content_type:
            logger.info(f"Skipping link extraction for non-HTML content type ({content_type}) at {current_url}")
            continue

        try:
            links_on_page = extract_links_from_html(html_content, current_url, base_domain)
            new_links_found = 0
            for link in links_on_page:
                if link not in discovered_urls:
                    discovered_urls.add(link)
                    queue.append(link)
                    new_links_found += 1
            if new_links_found > 0:
                logger.info(f"Found {new_links_found} new links on {current_url}. Queue size: {len(queue)}")
            else:
                logger.debug(f"No new links found on {current_url}.")

        except Exception as e:
            logger.error(f"Error parsing or extracting links from {current_url}: {e}", exc_info=True)
        
        time.sleep(REQUEST_DELAY)
    
    logger.info(f"Discovery finished. Total unique relevant URLs found: {len(discovered_urls)}")
    return sorted(list(discovered_urls))

# %%
def save_discovered_links(links, filepath):
    """
    Save the discovered links to a JSON file.
    """
    data = {
        'discovery_date': datetime.now().isoformat(),
        'start_url': START_URL,
        'base_url_domain': urlparse(BASE_URL).netloc,
        'count': len(links),
        'links': links
    }
    
    try:
        with open(filepath, 'w', encoding='utf-8') as f:
            json.dump(data, f, indent=2, ensure_ascii=False)
        logger.info(f"Successfully saved {len(links)} links to {filepath}")
    except IOError as e:
        logger.error(f"Failed to save links to {filepath}: {e}")
    return filepath

# %%
logger.info("--- Starting Link Discovery Process ---")
discovery_start_time = time.time()

# Discover all URLs
all_discovered_urls = discover_all_urls(START_URL)

if all_discovered_urls:
    # Save the links
    save_discovered_links(all_discovered_urls, LINKS_FILE)
    
    # Preview the links
    logger.info(f"\n--- Link Discovery Summary ---")
    logger.info(f"Discovery date: {datetime.now().isoformat()}")
    logger.info(f"Total links found: {len(all_discovered_urls)}")
    logger.info("\nSample links (first 10):")
    for link in all_discovered_urls[:10]:
        logger.info(f"  - {link}")
    if len(all_discovered_urls) > 10:
        logger.info("  ...")
else:
    logger.warning("No URLs were discovered. Check logs for errors.")

discovery_end_time = time.time()
elapsed_time = discovery_end_time - discovery_start_time
logger.info(f"--- Link Discovery Completed in {elapsed_time:.2f} seconds ---")
# Out:
# 2025-05-12 11:01:21,864 - INFO - 583492747 - <module> - --- Starting Link Discovery Process ---
# 2025-05-12 11:01:21,865 - INFO - 1551423106 - discover_all_urls - Starting URL discovery from: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/ (Domain: datascience.uchicago.edu)
# 2025-05-12 11:01:21,866 - INFO - 1551423106 - discover_all_urls - Processing 1/1: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science
# 2025-05-12 11:01:22,800 - INFO - 1551423106 - discover_all_urls - Found 64 new links on https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science. Queue size: 64
# 2025-05-12 11:01:22,901 - INFO - 1551423106 - discover_all_urls - Processing 2/128: https://datascience.uchicago.edu/insights/federal-budget-cuts-threaten-to-decimate-americas-ai-superiority-and-other-countries-are-watching
# 2025-05-12 11:01:23,174 - INFO - 1551423106 - discover_all_urls - Found 3 new links on https://datascience.uchicago.edu/insights/federal-budget-cuts-threaten-to-decimate-americas-ai-superiority-and-other-countries-are-watching. Queue size: 66
# 2025-05-12 11:01:23,276 - INFO - 1551423106 - discover_all_urls - Processing 3/133: https://datascience.uchicago.edu/news/rina-foygel-barber-and-margaret-gardel-elected-to-the-national-academy-of-sciences
# 2025-05-12 11:01:23,527 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/news/rina-foygel-barber-and-margaret-gardel-elected-to-the-national-academy-of-sciences. Queue size: 67
# 2025-05-12 11:01:23,628 - INFO - 1551423106 - discover_all_urls - Processing 4/136: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/in-person-program
# 2025-05-12 11:01:24,127 - INFO - 1551423106 - discover_all_urls - Found 15 new links on https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/in-person-program. Queue size: 81
# 2025-05-12 11:01:24,228 - INFO - 1551423106 - discover_all_urls - Processing 5/165: https://datascience.uchicago.edu/newsletter-archive
# 2025-05-12 11:01:24,587 - INFO - 1551423106 - discover_all_urls - Processing 6/164: https://datascience.uchicago.edu/people/affiliated-faculty
# 2025-05-12 11:01:24,865 - INFO - 1551423106 - discover_all_urls - Found 52 new links on https://datascience.uchicago.edu/people/affiliated-faculty. Queue size: 131
# 2025-05-12 11:01:24,967 - INFO - 1551423106 - discover_all_urls - Processing 7/267: https://datascience.uchicago.edu/insights/data-ecology-faculty-co-director-bridget-fahey-writes-about-congressional-authority-over-government-data
# 2025-05-12 11:01:25,219 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/insights/data-ecology-faculty-co-director-bridget-fahey-writes-about-congressional-authority-over-government-data. Queue size: 131
# 2025-05-12 11:01:25,320 - INFO - 1551423106 - discover_all_urls - Processing 8/268: https://datascience.uchicago.edu/about/about-dsi
# 2025-05-12 11:01:25,675 - INFO - 1551423106 - discover_all_urls - Processing 9/267: https://datascience.uchicago.edu/news/reflections-from-upcea-2025-exploring-data-science-and-ethics-in-higher-education
# 2025-05-12 11:01:25,943 - INFO - 1551423106 - discover_all_urls - Found 5 new links on https://datascience.uchicago.edu/news/reflections-from-upcea-2025-exploring-data-science-and-ethics-in-higher-education. Queue size: 134
# 2025-05-12 11:01:26,045 - INFO - 1551423106 - discover_all_urls - Processing 10/276: https://datascience.uchicago.edu/about/research-advisory-committee
# 2025-05-12 11:01:26,318 - INFO - 1551423106 - discover_all_urls - Found 6 new links on https://datascience.uchicago.edu/about/research-advisory-committee. Queue size: 139
# 2025-05-12 11:01:26,420 - INFO - 1551423106 - discover_all_urls - Processing 11/287: https://datascience.uchicago.edu/research/research-funding
# 2025-05-12 11:01:26,684 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/research/research-funding. Queue size: 140
# 2025-05-12 11:01:26,789 - INFO - 1551423106 - discover_all_urls - Processing 12/290: https://datascience.uchicago.edu/events/uncommon-core-ai-and-the-future-of-work-with-career-advancement
# 2025-05-12 11:01:27,045 - INFO - 1551423106 - discover_all_urls - Found 4 new links on https://datascience.uchicago.edu/events/uncommon-core-ai-and-the-future-of-work-with-career-advancement. Queue size: 143
# 2025-05-12 11:01:27,147 - INFO - 1551423106 - discover_all_urls - Processing 13/297: https://datascience.uchicago.edu/fellows-and-scholars
# 2025-05-12 11:01:27,523 - INFO - 1551423106 - discover_all_urls - Found 51 new links on https://datascience.uchicago.edu/fellows-and-scholars. Queue size: 193
# 2025-05-12 11:01:27,625 - INFO - 1551423106 - discover_all_urls - Processing 14/398: https://datascience.uchicago.edu/news/uchicago-data-mirror-website-launched-to-protect-access-to-public-datasets
# 2025-05-12 11:01:27,887 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/news/uchicago-data-mirror-website-launched-to-protect-access-to-public-datasets. Queue size: 194
# 2025-05-12 11:01:27,989 - INFO - 1551423106 - discover_all_urls - Processing 15/401: https://datascience.uchicago.edu/research/ai-science
# 2025-05-12 11:01:28,268 - INFO - 1551423106 - discover_all_urls - Found 62 new links on https://datascience.uchicago.edu/research/ai-science. Queue size: 255
# 2025-05-12 11:01:28,371 - INFO - 1551423106 - discover_all_urls - Processing 16/524: https://datascience.uchicago.edu/research/internet-equity
# 2025-05-12 11:01:28,633 - INFO - 1551423106 - discover_all_urls - Found 15 new links on https://datascience.uchicago.edu/research/internet-equity. Queue size: 269
# 2025-05-12 11:01:28,735 - INFO - 1551423106 - discover_all_urls - Processing 17/553: https://datascience.uchicago.edu/events/michelle-ntampaka-space-telescope-science-institute-aiscience-schmidt-fellows-speaker-series
# 2025-05-12 11:01:29,083 - INFO - 1551423106 - discover_all_urls - Processing 18/552: https://datascience.uchicago.edu/outreach/industry-partnerships
# 2025-05-12 11:01:29,344 - INFO - 1551423106 - discover_all_urls - Found 8 new links on https://datascience.uchicago.edu/outreach/industry-partnerships. Queue size: 275
# 2025-05-12 11:01:29,446 - INFO - 1551423106 - discover_all_urls - Processing 19/567: https://datascience.uchicago.edu/outreach/data-science-for-social-impact-network
# 2025-05-12 11:01:29,699 - INFO - 1551423106 - discover_all_urls - Found 15 new links on https://datascience.uchicago.edu/outreach/data-science-for-social-impact-network. Queue size: 289
# 2025-05-12 11:01:29,800 - INFO - 1551423106 - discover_all_urls - Processing 20/596: https://datascience.uchicago.edu/research/postdoctoral-programs
# 2025-05-12 11:01:30,061 - INFO - 1551423106 - discover_all_urls - Found 12 new links on https://datascience.uchicago.edu/research/postdoctoral-programs. Queue size: 300
# 2025-05-12 11:01:30,162 - INFO - 1551423106 - discover_all_urls - Processing 21/619: https://datascience.uchicago.edu/news/the-university-of-chicago-data-science-institute-and-google-partner-on-cutting-edge-ai-and-security-research
# 2025-05-12 11:01:30,420 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/news/the-university-of-chicago-data-science-institute-and-google-partner-on-cutting-edge-ai-and-security-research. Queue size: 301
# 2025-05-12 11:01:30,522 - INFO - 1551423106 - discover_all_urls - Processing 22/622: https://datascience.uchicago.edu/capstone-projects
# 2025-05-12 11:01:31,111 - INFO - 1551423106 - discover_all_urls - Processing 23/621: https://datascience.uchicago.edu/education/data-science-clinic
# 2025-05-12 11:01:31,376 - INFO - 1551423106 - discover_all_urls - Found 4 new links on https://datascience.uchicago.edu/education/data-science-clinic. Queue size: 303
# 2025-05-12 11:01:31,478 - INFO - 1551423106 - discover_all_urls - Processing 24/628: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/online-program
# 2025-05-12 11:01:31,978 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/online-program. Queue size: 303
# 2025-05-12 11:01:32,080 - INFO - 1551423106 - discover_all_urls - Processing 25/629: https://datascience.uchicago.edu/research/data-science-software-development-core
# 2025-05-12 11:01:32,337 - INFO - 1551423106 - discover_all_urls - Found 5 new links on https://datascience.uchicago.edu/research/data-science-software-development-core. Queue size: 307
# 2025-05-12 11:01:32,438 - INFO - 1551423106 - discover_all_urls - Processing 26/638: https://datascience.uchicago.edu/insights/whats-game-theoretic-about-statistics-a-game-theoretic-notion-of-evidence-and-cooperative-skepticism
# 2025-05-12 11:01:32,810 - INFO - 1551423106 - discover_all_urls - Processing 27/637: https://datascience.uchicago.edu/research/data-democracy
# 2025-05-12 11:01:33,090 - INFO - 1551423106 - discover_all_urls - Found 13 new links on https://datascience.uchicago.edu/research/data-democracy. Queue size: 318
# 2025-05-12 11:01:33,192 - INFO - 1551423106 - discover_all_urls - Processing 28/662: https://datascience.uchicago.edu/outreach/community-data-fellows
# 2025-05-12 11:01:33,454 - INFO - 1551423106 - discover_all_urls - Found 17 new links on https://datascience.uchicago.edu/outreach/community-data-fellows. Queue size: 334
# 2025-05-12 11:01:33,557 - INFO - 1551423106 - discover_all_urls - Processing 29/695: https://datascience.uchicago.edu/events/dsi-research-day-2
# 2025-05-12 11:01:33,913 - INFO - 1551423106 - discover_all_urls - Processing 30/694: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/online-program/%20
# 2025-05-12 11:01:34,767 - INFO - 1551423106 - discover_all_urls - Processing 31/693: https://datascience.uchicago.edu/research/outlier-research-evaluation
# 2025-05-12 11:01:35,048 - INFO - 1551423106 - discover_all_urls - Found 6 new links on https://datascience.uchicago.edu/research/outlier-research-evaluation. Queue size: 337
# 2025-05-12 11:01:35,150 - INFO - 1551423106 - discover_all_urls - Processing 32/704: https://datascience.uchicago.edu/education/summer-research-programs
# 2025-05-12 11:01:35,410 - INFO - 1551423106 - discover_all_urls - Found 5 new links on https://datascience.uchicago.edu/education/summer-research-programs. Queue size: 341
# 2025-05-12 11:01:35,512 - INFO - 1551423106 - discover_all_urls - Processing 33/713: https://datascience.uchicago.edu/news/dsi-and-the-patrick-j-mcgovern-foundation-invite-the-next-generation-to-imagine-data-and-ai-for-good
# 2025-05-12 11:01:35,770 - INFO - 1551423106 - discover_all_urls - Found 5 new links on https://datascience.uchicago.edu/news/dsi-and-the-patrick-j-mcgovern-foundation-invite-the-next-generation-to-imagine-data-and-ai-for-good. Queue size: 345
# 2025-05-12 11:01:35,871 - INFO - 1551423106 - discover_all_urls - Processing 34/722: https://datascience.uchicago.edu/nondiscrimination-statement
# 2025-05-12 11:01:36,248 - INFO - 1551423106 - discover_all_urls - Processing 35/721: https://datascience.uchicago.edu/education/undergrad-major
# 2025-05-12 11:01:36,515 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/education/undergrad-major. Queue size: 345
# 2025-05-12 11:01:36,617 - INFO - 1551423106 - discover_all_urls - Processing 36/724: https://datascience.uchicago.edu/about/contact
# 2025-05-12 11:01:36,985 - INFO - 1551423106 - discover_all_urls - Processing 37/723: https://datascience.uchicago.edu/education
# 2025-05-12 11:01:37,349 - INFO - 1551423106 - discover_all_urls - Processing 38/722: https://datascience.uchicago.edu/research/complementary-ai
# 2025-05-12 11:01:37,605 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/research/complementary-ai. Queue size: 344
# 2025-05-12 11:01:37,707 - INFO - 1551423106 - discover_all_urls - Processing 39/725: https://datascience.uchicago.edu/events/chicago-data-night-eve-jennings-city-of-chicago
# 2025-05-12 11:01:37,961 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/events/chicago-data-night-eve-jennings-city-of-chicago. Queue size: 344
# 2025-05-12 11:01:38,064 - INFO - 1551423106 - discover_all_urls - Processing 40/726: https://datascience.uchicago.edu/how-to-apply
# 2025-05-12 11:01:38,549 - INFO - 1551423106 - discover_all_urls - Found 3 new links on https://datascience.uchicago.edu/how-to-apply. Queue size: 346
# 2025-05-12 11:01:38,652 - INFO - 1551423106 - discover_all_urls - Processing 41/731: https://datascience.uchicago.edu/outreach
# 2025-05-12 11:01:38,913 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/outreach. Queue size: 346
# 2025-05-12 11:01:39,015 - INFO - 1551423106 - discover_all_urls - Processing 42/732: https://datascience.uchicago.edu/events/ms-in-applied-data-science-information-session-in-person-program-5
# 2025-05-12 11:01:39,275 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/events/ms-in-applied-data-science-information-session-in-person-program-5. Queue size: 346
# 2025-05-12 11:01:39,376 - INFO - 1551423106 - discover_all_urls - Processing 43/733: https://datascience.uchicago.edu/about/visiting-dsi
# 2025-05-12 11:01:39,729 - INFO - 1551423106 - discover_all_urls - Processing 44/732: https://datascience.uchicago.edu/news-events/events
# 2025-05-12 11:01:39,994 - INFO - 1551423106 - discover_all_urls - Found 10 new links on https://datascience.uchicago.edu/news-events/events. Queue size: 354
# 2025-05-12 11:01:40,097 - INFO - 1551423106 - discover_all_urls - Processing 45/751: https://datascience.uchicago.edu/about
# 2025-05-12 11:01:40,449 - INFO - 1551423106 - discover_all_urls - Processing 46/750: https://datascience.uchicago.edu/about/jobs
# 2025-05-12 11:01:40,712 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/about/jobs. Queue size: 354
# 2025-05-12 11:01:40,815 - INFO - 1551423106 - discover_all_urls - Processing 47/753: https://datascience.uchicago.edu/about/leadership-staff
# 2025-05-12 11:01:41,143 - INFO - 1551423106 - discover_all_urls - Found 47 new links on https://datascience.uchicago.edu/about/leadership-staff. Queue size: 400
# 2025-05-12 11:01:41,244 - INFO - 1551423106 - discover_all_urls - Processing 48/846: https://datascience.uchicago.edu/outreach/preceptors
# 2025-05-12 11:01:41,506 - INFO - 1551423106 - discover_all_urls - Found 4 new links on https://datascience.uchicago.edu/outreach/preceptors. Queue size: 403
# 2025-05-12 11:01:41,608 - INFO - 1551423106 - discover_all_urls - Processing 49/853: https://datascience.uchicago.edu/research
# 2025-05-12 11:01:41,916 - INFO - 1551423106 - discover_all_urls - Found 25 new links on https://datascience.uchicago.edu/research. Queue size: 427
# 2025-05-12 11:01:42,017 - INFO - 1551423106 - discover_all_urls - Processing 50/902: https://datascience.uchicago.edu/outreach/data4all
# 2025-05-12 11:01:42,274 - INFO - 1551423106 - discover_all_urls - Found 5 new links on https://datascience.uchicago.edu/outreach/data4all. Queue size: 431
# 2025-05-12 11:01:42,376 - INFO - 1551423106 - discover_all_urls - Processing 51/911: https://datascience.uchicago.edu/education/masters-programs
# 2025-05-12 11:01:42,649 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/education/masters-programs. Queue size: 432
# 2025-05-12 11:01:42,751 - INFO - 1551423106 - discover_all_urls - Processing 52/914: https://datascience.uchicago.edu/events/ai-science-summer-school-2025
# 2025-05-12 11:01:43,165 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/events/ai-science-summer-school-2025. Queue size: 432
# 2025-05-12 11:01:43,267 - INFO - 1551423106 - discover_all_urls - Processing 53/915: https://datascience.uchicago.edu/about-us
# 2025-05-12 11:01:44,009 - INFO - 1551423106 - discover_all_urls - Found 29 new links on https://datascience.uchicago.edu/about-us. Queue size: 460
# 2025-05-12 11:01:44,112 - INFO - 1551423106 - discover_all_urls - Processing 54/972: https://datascience.uchicago.edu/news/novel-machine-learning-approaches-to-facilitate-skin-cancer-detection
# 2025-05-12 11:01:44,463 - INFO - 1551423106 - discover_all_urls - Processing 55/971: https://datascience.uchicago.edu/research/open-spatial-lab
# 2025-05-12 11:01:44,723 - INFO - 1551423106 - discover_all_urls - Found 6 new links on https://datascience.uchicago.edu/research/open-spatial-lab. Queue size: 464
# 2025-05-12 11:01:44,825 - INFO - 1551423106 - discover_all_urls - Processing 56/982: https://datascience.uchicago.edu/outreach/11th-hour-project
# 2025-05-12 11:01:45,095 - INFO - 1551423106 - discover_all_urls - Found 6 new links on https://datascience.uchicago.edu/outreach/11th-hour-project. Queue size: 469
# 2025-05-12 11:01:45,199 - INFO - 1551423106 - discover_all_urls - Processing 57/993: https://datascience.uchicago.edu/education/phd-in-data-science
# 2025-05-12 11:01:45,550 - INFO - 1551423106 - discover_all_urls - Processing 58/992: https://datascience.uchicago.edu/research/projects
# 2025-05-12 11:01:45,946 - INFO - 1551423106 - discover_all_urls - Processing 59/991: https://datascience.uchicago.edu/research/aice-ai-for-climate
# 2025-05-12 11:01:46,204 - INFO - 1551423106 - discover_all_urls - Found 4 new links on https://datascience.uchicago.edu/research/aice-ai-for-climate. Queue size: 470
# 2025-05-12 11:01:46,305 - INFO - 1551423106 - discover_all_urls - Processing 60/998: https://datascience.uchicago.edu/news-events/news
# 2025-05-12 11:01:46,569 - INFO - 1551423106 - discover_all_urls - Found 3 new links on https://datascience.uchicago.edu/news-events/news. Queue size: 472
# 2025-05-12 11:01:46,671 - INFO - 1551423106 - discover_all_urls - Processing 61/1003: https://datascience.uchicago.edu/
# 2025-05-12 11:01:46,933 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/. Queue size: 473
# 2025-05-12 11:01:47,035 - INFO - 1551423106 - discover_all_urls - Processing 62/1006: https://datascience.uchicago.edu/events/tianyu-gao-princeton-computer-science-and-dsi-joint-colloquium
# 2025-05-12 11:01:47,388 - INFO - 1551423106 - discover_all_urls - Processing 63/1005: https://datascience.uchicago.edu/events/dimitris-giannakis-dartmouth-cam-and-dsi-joint-colloquium
# 2025-05-12 11:01:47,744 - INFO - 1551423106 - discover_all_urls - Processing 64/1004: https://datascience.uchicago.edu/research/data-ecology
# 2025-05-12 11:01:48,003 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/research/data-ecology. Queue size: 471
# 2025-05-12 11:01:48,104 - INFO - 1551423106 - discover_all_urls - Processing 65/1005: https://datascience.uchicago.edu/insights
# 2025-05-12 11:01:48,371 - INFO - 1551423106 - discover_all_urls - Found 3 new links on https://datascience.uchicago.edu/insights. Queue size: 473
# 2025-05-12 11:01:48,473 - INFO - 1551423106 - discover_all_urls - Processing 66/1010: https://datascience.uchicago.edu/insights/the-challenging-path-to-internet-broadband-access-equity
# 2025-05-12 11:01:48,841 - INFO - 1551423106 - discover_all_urls - Processing 67/1009: https://datascience.uchicago.edu/insights/behind-automatic-video-semantic-segmentation
# 2025-05-12 11:01:49,216 - INFO - 1551423106 - discover_all_urls - Processing 68/1008: https://datascience.uchicago.edu/insights/does-political-polarization-really-undermine-democracy-maybe-not
# 2025-05-12 11:01:49,581 - INFO - 1551423106 - discover_all_urls - Processing 69/1007: https://datascience.uchicago.edu/people/margaret-gardel
# 2025-05-12 11:01:49,940 - INFO - 1551423106 - discover_all_urls - Processing 70/1006: https://datascience.uchicago.edu/people/rina-foygel-barber
# 2025-05-12 11:01:50,318 - INFO - 1551423106 - discover_all_urls - Processing 71/1005: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/events-deadlines
# 2025-05-12 11:01:50,689 - INFO - 1551423106 - discover_all_urls - Processing 72/1004: https://datascience.uchicago.edu/education/masters-programs/online-program
# 2025-05-12 11:01:51,302 - INFO - 1551423106 - discover_all_urls - Processing 73/1003: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/tuition-fees-aid
# 2025-05-12 11:01:51,917 - INFO - 1551423106 - discover_all_urls - Processing 74/1002: https://datascience.uchicago.edu/education/tuition-fees-aid
# 2025-05-12 11:01:52,267 - INFO - 1551423106 - discover_all_urls - Processing 75/1001: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/career-outcomes
# 2025-05-12 11:01:52,630 - INFO - 1551423106 - discover_all_urls - Processing 76/1000: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/our-students
# 2025-05-12 11:01:52,889 - INFO - 1551423106 - discover_all_urls - Found 5 new links on https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/our-students. Queue size: 467
# 2025-05-12 11:01:52,990 - INFO - 1551423106 - discover_all_urls - Processing 77/1009: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/faqs
# 2025-05-12 11:01:53,403 - INFO - 1551423106 - discover_all_urls - Processing 78/1008: https://datascience.uchicago.edu/education/masters-programs/in-person-program
# 2025-05-12 11:01:53,760 - INFO - 1551423106 - discover_all_urls - Processing 79/1007: https://datascience.uchicago.edu/people/greg-green
# 2025-05-12 11:01:54,123 - INFO - 1551423106 - discover_all_urls - Processing 80/1006: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/how-to-apply
# 2025-05-12 11:01:54,485 - INFO - 1551423106 - discover_all_urls - Processing 81/1005: https://datascience.uchicago.edu/test-course-progressions
# 2025-05-12 11:01:55,078 - INFO - 1551423106 - discover_all_urls - Processing 82/1004: https://datascience.uchicago.edu/explore-the-ms-ads-campus
# 2025-05-12 11:01:55,434 - INFO - 1551423106 - discover_all_urls - Processing 83/1003: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/course-progressions
# 2025-05-12 11:01:55,817 - INFO - 1551423106 - discover_all_urls - Processing 84/1002: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/instructors-staff
# 2025-05-12 11:01:56,234 - INFO - 1551423106 - discover_all_urls - Processing 85/1001: https://datascience.uchicago.edu/education/masters-programs/ms-in-applied-data-science/capstone-projects
# 2025-05-12 11:01:56,587 - INFO - 1551423106 - discover_all_urls - Processing 86/1000: https://datascience.uchicago.edu/people/nicole-marwell
# 2025-05-12 11:01:56,940 - INFO - 1551423106 - discover_all_urls - Processing 87/999: https://datascience.uchicago.edu/people/yuxin-chen
# 2025-05-12 11:01:57,298 - INFO - 1551423106 - discover_all_urls - Processing 88/998: https://datascience.uchicago.edu/people/karen-livescu
# 2025-05-12 11:01:57,659 - INFO - 1551423106 - discover_all_urls - Processing 89/997: https://datascience.uchicago.edu/people/lorenzo-orecchia
# 2025-05-12 11:01:58,022 - INFO - 1551423106 - discover_all_urls - Processing 90/996: https://datascience.uchicago.edu/people/joshua-conrad-jackson
# 2025-05-12 11:01:58,380 - INFO - 1551423106 - discover_all_urls - Processing 91/995: https://datascience.uchicago.edu/people/marshini-chetty
# 2025-05-12 11:01:58,836 - INFO - 1551423106 - discover_all_urls - Processing 92/994: https://datascience.uchicago.edu/people/marc-berman
# 2025-05-12 11:01:59,195 - INFO - 1551423106 - discover_all_urls - Processing 93/993: https://datascience.uchicago.edu/people/mentor-anjali-adukia-2
# 2025-05-12 11:01:59,544 - INFO - 1551423106 - discover_all_urls - Processing 94/992: https://datascience.uchicago.edu/people/andrew-ferguson
# 2025-05-12 11:01:59,906 - INFO - 1551423106 - discover_all_urls - Processing 95/991: https://datascience.uchicago.edu/people/joshua-frieman
# 2025-05-12 11:02:00,260 - INFO - 1551423106 - discover_all_urls - Processing 96/990: https://datascience.uchicago.edu/people/nati-srebro
# 2025-05-12 11:02:00,607 - INFO - 1551423106 - discover_all_urls - Processing 97/989: https://datascience.uchicago.edu/people/blase-ur
# 2025-05-12 11:02:00,966 - INFO - 1551423106 - discover_all_urls - Processing 98/988: https://datascience.uchicago.edu/people/aaron-dinner
# 2025-05-12 11:02:01,319 - INFO - 1551423106 - discover_all_urls - Processing 99/987: https://datascience.uchicago.edu/people/claire-donnat
# 2025-05-12 11:02:01,676 - INFO - 1551423106 - discover_all_urls - Processing 100/986: https://datascience.uchicago.edu/people/junhong-chen
# 2025-05-12 11:02:02,037 - INFO - 1551423106 - discover_all_urls - Processing 101/985: https://datascience.uchicago.edu/people/jiwen-fan
# 2025-05-12 11:02:02,397 - INFO - 1551423106 - discover_all_urls - Processing 102/984: https://datascience.uchicago.edu/people/luc-anselin
# 2025-05-12 11:02:02,760 - INFO - 1551423106 - discover_all_urls - Processing 103/983: https://datascience.uchicago.edu/people/amir-jina
# 2025-05-12 11:02:03,126 - INFO - 1551423106 - discover_all_urls - Processing 104/982: https://datascience.uchicago.edu/people/yuehaw-khoo
# 2025-05-12 11:02:03,506 - INFO - 1551423106 - discover_all_urls - Processing 105/981: https://datascience.uchicago.edu/people/cong-ma
# 2025-05-12 11:02:03,856 - INFO - 1551423106 - discover_all_urls - Processing 106/980: https://datascience.uchicago.edu/people/christopher-berry
# 2025-05-12 11:02:04,207 - INFO - 1551423106 - discover_all_urls - Processing 107/979: https://datascience.uchicago.edu/engage/partnerships
# 2025-05-12 11:02:04,691 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/engage/partnerships. Queue size: 437
# 2025-05-12 11:02:04,793 - INFO - 1551423106 - discover_all_urls - Processing 108/980: https://datascience.uchicago.edu/people/ian-foster
# 2025-05-12 11:02:05,155 - INFO - 1551423106 - discover_all_urls - Processing 109/979: https://datascience.uchicago.edu/people/bridget-fahey
# 2025-05-12 11:02:05,507 - INFO - 1551423106 - discover_all_urls - Processing 110/978: https://datascience.uchicago.edu/people/kate-keahey
# 2025-05-12 11:02:05,855 - INFO - 1551423106 - discover_all_urls - Processing 111/977: https://datascience.uchicago.edu/people/maryellen-giger
# 2025-05-12 11:02:06,214 - INFO - 1551423106 - discover_all_urls - Processing 112/976: https://datascience.uchicago.edu/people/samantha-riesenfeld
# 2025-05-12 11:02:06,577 - INFO - 1551423106 - discover_all_urls - Processing 113/975: https://datascience.uchicago.edu/people/david-miller
# 2025-05-12 11:02:06,938 - INFO - 1551423106 - discover_all_urls - Processing 114/974: https://datascience.uchicago.edu/people/matthew-stephens
# 2025-05-12 11:02:07,291 - INFO - 1551423106 - discover_all_urls - Processing 115/973: https://datascience.uchicago.edu/people/hae-kyung-im
# 2025-05-12 11:02:07,657 - INFO - 1551423106 - discover_all_urls - Processing 116/972: https://datascience.uchicago.edu/people/pedram-hassanzadeh
# 2025-05-12 11:02:08,007 - INFO - 1551423106 - discover_all_urls - Processing 117/971: https://datascience.uchicago.edu/people/yuan-chang-leong
# 2025-05-12 11:02:08,367 - INFO - 1551423106 - discover_all_urls - Processing 118/970: https://datascience.uchicago.edu/people/jingshu-wang
# 2025-05-12 11:02:08,714 - INFO - 1551423106 - discover_all_urls - Processing 119/969: https://datascience.uchicago.edu/people/tiffany-shaw
# 2025-05-12 11:02:09,072 - INFO - 1551423106 - discover_all_urls - Processing 120/968: https://datascience.uchicago.edu/people/raul-castro-fernandez
# 2025-05-12 11:02:09,330 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/people/raul-castro-fernandez. Queue size: 425
# 2025-05-12 11:02:09,432 - INFO - 1551423106 - discover_all_urls - Processing 121/969: https://datascience.uchicago.edu/people/molly-offer-westort
# 2025-05-12 11:02:09,805 - INFO - 1551423106 - discover_all_urls - Processing 122/968: https://datascience.uchicago.edu/people/rana-hanocka
# 2025-05-12 11:02:10,165 - INFO - 1551423106 - discover_all_urls - Processing 123/967: https://datascience.uchicago.edu/engage/fellowships
# 2025-05-12 11:02:10,646 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/engage/fellowships. Queue size: 423
# 2025-05-12 11:02:10,747 - INFO - 1551423106 - discover_all_urls - Processing 124/968: https://datascience.uchicago.edu/people/luis-m-a-bettencourt
# 2025-05-12 11:02:11,099 - INFO - 1551423106 - discover_all_urls - Processing 125/967: https://datascience.uchicago.edu/people/daniel-sanz-alonso
# 2025-05-12 11:02:11,457 - INFO - 1551423106 - discover_all_urls - Processing 126/966: https://datascience.uchicago.edu/people/vincenzo-vitelli
# 2025-05-12 11:02:11,819 - INFO - 1551423106 - discover_all_urls - Processing 127/965: https://datascience.uchicago.edu/people/risi-kondor
# 2025-05-12 11:02:12,179 - INFO - 1551423106 - discover_all_urls - Processing 128/964: https://datascience.uchicago.edu/people/samuel-l-volchenboum
# 2025-05-12 11:02:12,542 - INFO - 1551423106 - discover_all_urls - Processing 129/963: https://datascience.uchicago.edu/people/robert-grossman
# 2025-05-12 11:02:12,895 - INFO - 1551423106 - discover_all_urls - Processing 130/962: https://datascience.uchicago.edu/people/james-evans
# 2025-05-12 11:02:13,252 - INFO - 1551423106 - discover_all_urls - Processing 131/961: https://datascience.uchicago.edu/people/kyle-chard
# 2025-05-12 11:02:13,610 - INFO - 1551423106 - discover_all_urls - Processing 132/960: https://datascience.uchicago.edu/people/david-freedman
# 2025-05-12 11:02:13,969 - INFO - 1551423106 - discover_all_urls - Processing 133/959: https://datascience.uchicago.edu/people/aaron-j-elmore
# 2025-05-12 11:02:14,324 - INFO - 1551423106 - discover_all_urls - Processing 134/958: https://datascience.uchicago.edu/people
# 2025-05-12 11:02:14,688 - INFO - 1551423106 - discover_all_urls - Processing 135/957: https://datascience.uchicago.edu/people/sanjay-krishnan
# 2025-05-12 11:02:15,045 - INFO - 1551423106 - discover_all_urls - Processing 136/956: https://datascience.uchicago.edu/people/veronika-rockova
# 2025-05-12 11:02:15,406 - INFO - 1551423106 - discover_all_urls - Processing 137/955: https://datascience.uchicago.edu/people/chibueze-amanchukwu
# 2025-05-12 11:02:15,766 - INFO - 1551423106 - discover_all_urls - Processing 138/954: https://datascience.uchicago.edu/insights/developing-a-smart-material-that-can-learn-from-example
# 2025-05-12 11:02:16,122 - INFO - 1551423106 - discover_all_urls - Processing 139/953: https://datascience.uchicago.edu/people/brody-tate
# 2025-05-12 11:02:16,582 - INFO - 1551423106 - discover_all_urls - Processing 140/952: https://datascience.uchicago.edu/people/emma-kerr
# 2025-05-12 11:02:16,945 - INFO - 1551423106 - discover_all_urls - Processing 141/951: https://datascience.uchicago.edu/news/a-day-at-google-for-uchicagos-ms-in-applied-data-science-students
# 2025-05-12 11:02:17,225 - INFO - 1551423106 - discover_all_urls - Found 13 new links on https://datascience.uchicago.edu/news/a-day-at-google-for-uchicagos-ms-in-applied-data-science-students. Queue size: 418
# 2025-05-12 11:02:17,328 - INFO - 1551423106 - discover_all_urls - Processing 142/976: https://datascience.uchicago.edu/news/applied-data-science-students-craft-ai-powered-storytelling-app
# 2025-05-12 11:02:17,594 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/news/applied-data-science-students-craft-ai-powered-storytelling-app. Queue size: 419
# 2025-05-12 11:02:17,696 - INFO - 1551423106 - discover_all_urls - Processing 143/979: https://datascience.uchicago.edu/people/taylor-alexander
# 2025-05-12 11:02:18,051 - INFO - 1551423106 - discover_all_urls - Processing 144/978: https://datascience.uchicago.edu/people/chris-kennedy
# 2025-05-12 11:02:18,412 - INFO - 1551423106 - discover_all_urls - Processing 145/977: https://datascience.uchicago.edu/people/michael-j-franklin
# 2025-05-12 11:02:18,668 - INFO - 1551423106 - discover_all_urls - Found 6 new links on https://datascience.uchicago.edu/people/michael-j-franklin. Queue size: 422
# 2025-05-12 11:02:18,770 - INFO - 1551423106 - discover_all_urls - Processing 146/988: https://datascience.uchicago.edu/people/dan-nicolae
# 2025-05-12 11:02:19,034 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/people/dan-nicolae. Queue size: 422
# 2025-05-12 11:02:19,135 - INFO - 1551423106 - discover_all_urls - Processing 147/989: https://datascience.uchicago.edu/people/sendhil-mullainathan
# 2025-05-12 11:02:19,497 - INFO - 1551423106 - discover_all_urls - Processing 148/988: https://datascience.uchicago.edu/people/rebecca-willett
# 2025-05-12 11:02:19,773 - INFO - 1551423106 - discover_all_urls - Found 5 new links on https://datascience.uchicago.edu/people/rebecca-willett. Queue size: 425
# 2025-05-12 11:02:19,875 - INFO - 1551423106 - discover_all_urls - Processing 149/997: https://datascience.uchicago.edu/people/nick-feamster
# 2025-05-12 11:02:20,151 - INFO - 1551423106 - discover_all_urls - Found 4 new links on https://datascience.uchicago.edu/people/nick-feamster. Queue size: 428
# 2025-05-12 11:02:20,253 - INFO - 1551423106 - discover_all_urls - Processing 150/1004: https://datascience.uchicago.edu/research/research-funding/dsi-research-initiative-request-for-proposals
# 2025-05-12 11:02:20,607 - INFO - 1551423106 - discover_all_urls - Processing 151/1003: https://datascience.uchicago.edu/research/research-funding/ai-science-research-funding-opportunities
# 2025-05-12 11:02:20,985 - INFO - 1551423106 - discover_all_urls - Processing 152/1002: https://datascience.uchicago.edu/events/esteban-real-automatically-discovering-learning-algorithms-with-hardware-constraints
# 2025-05-12 11:02:21,247 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/events/esteban-real-automatically-discovering-learning-algorithms-with-hardware-constraints. Queue size: 427
# 2025-05-12 11:02:21,349 - INFO - 1551423106 - discover_all_urls - Processing 153/1005: https://datascience.uchicago.edu/events/data-ethics-and-policy-conference-2024-governance-in-a-digital-world
# 2025-05-12 11:02:21,704 - INFO - 1551423106 - discover_all_urls - Processing 154/1004: https://datascience.uchicago.edu/events/nsf-workshop-on-data-driven-modeling-and-prediction-of-rare-and-extreme-events
# 2025-05-12 11:02:21,969 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/events/nsf-workshop-on-data-driven-modeling-and-prediction-of-rare-and-extreme-events. Queue size: 426
# 2025-05-12 11:02:22,071 - INFO - 1551423106 - discover_all_urls - Processing 155/1005: https://datascience.uchicago.edu/events/max-nickel-fair-meta-ai-towards-social-foundations-of-ai
# 2025-05-12 11:02:22,327 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/events/max-nickel-fair-meta-ai-towards-social-foundations-of-ai. Queue size: 426
# 2025-05-12 11:02:22,429 - INFO - 1551423106 - discover_all_urls - Processing 156/1006: https://datascience.uchicago.edu/people/thomas-callister
# 2025-05-12 11:02:22,787 - INFO - 1551423106 - discover_all_urls - Processing 157/1005: https://datascience.uchicago.edu/people/huanqiu-zhang
# 2025-05-12 11:02:23,141 - INFO - 1551423106 - discover_all_urls - Processing 158/1004: https://datascience.uchicago.edu/people/rituparno-mandal
# 2025-05-12 11:02:23,509 - INFO - 1551423106 - discover_all_urls - Processing 159/1003: https://datascience.uchicago.edu/people/adam-fouda
# 2025-05-12 11:02:23,875 - INFO - 1551423106 - discover_all_urls - Processing 160/1002: https://datascience.uchicago.edu/people/isaac-mehlhaff
# 2025-05-12 11:02:24,229 - INFO - 1551423106 - discover_all_urls - Processing 161/1001: https://datascience.uchicago.edu/people/kriti-sehgal
# 2025-05-12 11:02:24,582 - INFO - 1551423106 - discover_all_urls - Processing 162/1000: https://datascience.uchicago.edu/people/patricia-chiril
# 2025-05-12 11:02:24,936 - INFO - 1551423106 - discover_all_urls - Processing 163/999: https://datascience.uchicago.edu/people/jonatas-marques
# 2025-05-12 11:02:25,297 - INFO - 1551423106 - discover_all_urls - Processing 164/998: https://datascience.uchicago.edu/people/seyed-a-esmaeili
# 2025-05-12 11:02:25,652 - INFO - 1551423106 - discover_all_urls - Processing 165/997: https://datascience.uchicago.edu/people/riley-tucker
# 2025-05-12 11:02:25,901 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/people/riley-tucker. Queue size: 417
# 2025-05-12 11:02:26,002 - INFO - 1551423106 - discover_all_urls - Processing 166/998: https://datascience.uchicago.edu/people/kristina-herman
# 2025-05-12 11:02:26,355 - INFO - 1551423106 - discover_all_urls - Processing 167/997: https://datascience.uchicago.edu/people/martin-falk
# 2025-05-12 11:02:26,730 - INFO - 1551423106 - discover_all_urls - Processing 168/996: https://datascience.uchicago.edu/people/shailaja-seetharaman
# 2025-05-12 11:02:27,080 - INFO - 1551423106 - discover_all_urls - Processing 169/995: https://datascience.uchicago.edu/people/anthony-badea
# 2025-05-12 11:02:27,437 - INFO - 1551423106 - discover_all_urls - Processing 170/994: https://datascience.uchicago.edu/people/julia-mendelsohn
# 2025-05-12 11:02:27,807 - INFO - 1551423106 - discover_all_urls - Processing 171/993: https://datascience.uchicago.edu/people/tarun-mangla
# 2025-05-12 11:02:28,178 - INFO - 1551423106 - discover_all_urls - Processing 172/992: https://datascience.uchicago.edu/people/francesco-pinto
# 2025-05-12 11:02:28,550 - INFO - 1551423106 - discover_all_urls - Processing 173/991: https://datascience.uchicago.edu/people/vasilis-charisopoulos
# 2025-05-12 11:02:28,909 - INFO - 1551423106 - discover_all_urls - Processing 174/990: https://datascience.uchicago.edu/people/ganghua-wang
# 2025-05-12 11:02:29,261 - INFO - 1551423106 - discover_all_urls - Processing 175/989: https://datascience.uchicago.edu/people/chong-liu
# 2025-05-12 11:02:29,612 - INFO - 1551423106 - discover_all_urls - Processing 176/988: https://datascience.uchicago.edu/people/susanna-lange
# 2025-05-12 11:02:29,992 - INFO - 1551423106 - discover_all_urls - Processing 177/987: https://datascience.uchicago.edu/people/jeffrey-negrea-2
# 2025-05-12 11:02:30,355 - INFO - 1551423106 - discover_all_urls - Processing 178/986: https://datascience.uchicago.edu/people/jingchao-fang
# 2025-05-12 11:02:30,722 - INFO - 1551423106 - discover_all_urls - Processing 179/985: https://datascience.uchicago.edu/people/ramanujan-srinath
# 2025-05-12 11:02:31,081 - INFO - 1551423106 - discover_all_urls - Processing 180/984: https://datascience.uchicago.edu/people/ritesh-kumar
# 2025-05-12 11:02:31,448 - INFO - 1551423106 - discover_all_urls - Processing 181/983: https://datascience.uchicago.edu/people/william-denault
# 2025-05-12 11:02:31,806 - INFO - 1551423106 - discover_all_urls - Processing 182/982: https://datascience.uchicago.edu/people/jie-jian
# 2025-05-12 11:02:32,158 - INFO - 1551423106 - discover_all_urls - Processing 183/981: https://datascience.uchicago.edu/people/judit-prat-marti
# 2025-05-12 11:02:32,510 - INFO - 1551423106 - discover_all_urls - Processing 184/980: https://datascience.uchicago.edu/people/yj-choe
# 2025-05-12 11:02:32,860 - INFO - 1551423106 - discover_all_urls - Processing 185/979: https://datascience.uchicago.edu/people/ava-ghezelayagh
# 2025-05-12 11:02:33,354 - INFO - 1551423106 - discover_all_urls - Processing 186/978: https://datascience.uchicago.edu/people/bill-trok
# 2025-05-12 11:02:33,702 - INFO - 1551423106 - discover_all_urls - Processing 187/977: https://datascience.uchicago.edu/people/jordan-shivers
# 2025-05-12 11:02:34,050 - INFO - 1551423106 - discover_all_urls - Processing 188/976: https://datascience.uchicago.edu/people/jamie-saxon
# 2025-05-12 11:02:34,402 - INFO - 1551423106 - discover_all_urls - Processing 189/975: https://datascience.uchicago.edu/people/peter-lu
# 2025-05-12 11:02:34,760 - INFO - 1551423106 - discover_all_urls - Processing 190/974: https://datascience.uchicago.edu/people/shi-feng
# 2025-05-12 11:02:35,112 - INFO - 1551423106 - discover_all_urls - Processing 191/973: https://datascience.uchicago.edu/people/yuetian-luo
# 2025-05-12 11:02:35,474 - INFO - 1551423106 - discover_all_urls - Processing 192/972: https://datascience.uchicago.edu/people/teresa-flanagan
# 2025-05-12 11:02:35,841 - INFO - 1551423106 - discover_all_urls - Processing 193/971: https://datascience.uchicago.edu/people/georgios-valogiannis
# 2025-05-12 11:02:36,193 - INFO - 1551423106 - discover_all_urls - Processing 194/970: https://datascience.uchicago.edu/people/meghan-hutch-she-her
# 2025-05-12 11:02:36,553 - INFO - 1551423106 - discover_all_urls - Processing 195/969: https://datascience.uchicago.edu/people/rui-ding
# 2025-05-12 11:02:36,928 - INFO - 1551423106 - discover_all_urls - Processing 196/968: https://datascience.uchicago.edu/people/satadisha-saha-bhowmick
# 2025-05-12 11:02:37,286 - INFO - 1551423106 - discover_all_urls - Processing 197/967: https://datascience.uchicago.edu/people/sainyam-galhotra
# 2025-05-12 11:02:37,645 - INFO - 1551423106 - discover_all_urls - Processing 198/966: https://datascience.uchicago.edu/people/aditya-nandy
# 2025-05-12 11:02:38,023 - INFO - 1551423106 - discover_all_urls - Processing 199/965: https://datascience.uchicago.edu/people/cristina-garbacea
# 2025-05-12 11:02:38,370 - INFO - 1551423106 - discover_all_urls - Processing 200/964: https://datascience.uchicago.edu/people/madeleine-torcasso
# 2025-05-12 11:02:38,728 - INFO - 1551423106 - discover_all_urls - Processing 201/963: https://datascience.uchicago.edu/people/ludwig-schneider
# 2025-05-12 11:02:39,094 - INFO - 1551423106 - discover_all_urls - Processing 202/962: https://datascience.uchicago.edu/people/yihang-wang
# 2025-05-12 11:02:39,452 - INFO - 1551423106 - discover_all_urls - Processing 203/961: https://datascience.uchicago.edu/people/kelly-smalenberger
# 2025-05-12 11:02:39,804 - INFO - 1551423106 - discover_all_urls - Processing 204/960: https://datascience.uchicago.edu/people/dylan-fitzpatrick
# 2025-05-12 11:02:40,157 - INFO - 1551423106 - discover_all_urls - Processing 205/959: https://datascience.uchicago.edu/people/alexander-bogatskiy-2
# 2025-05-12 11:02:40,512 - INFO - 1551423106 - discover_all_urls - Processing 206/958: https://datascience.uchicago.edu/people/colm-talbot
# 2025-05-12 11:02:40,881 - INFO - 1551423106 - discover_all_urls - Processing 207/957: https://datascience.uchicago.edu/people/dylan-halpern
# 2025-05-12 11:02:41,304 - INFO - 1551423106 - discover_all_urls - Processing 208/956: https://datascience.uchicago.edu/people/nick-ross
# 2025-05-12 11:02:41,579 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/people/nick-ross. Queue size: 376
# 2025-05-12 11:02:41,681 - INFO - 1551423106 - discover_all_urls - Processing 209/959: https://datascience.uchicago.edu/research/ai-science/partnerships/pritzker-aiscience-joint-initiative-with-caltech
# 2025-05-12 11:02:41,960 - INFO - 1551423106 - discover_all_urls - Found 15 new links on https://datascience.uchicago.edu/research/ai-science/partnerships/pritzker-aiscience-joint-initiative-with-caltech. Queue size: 390
# 2025-05-12 11:02:42,062 - INFO - 1551423106 - discover_all_urls - Processing 210/988: https://datascience.uchicago.edu/insights/modeling-chaos-using-machine-learning-emulators
# 2025-05-12 11:02:42,423 - INFO - 1551423106 - discover_all_urls - Processing 211/987: https://datascience.uchicago.edu/insights/machine-learning-foundations-accelerate-innovation-and-promote-trustworthiness
# 2025-05-12 11:02:42,681 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/insights/machine-learning-foundations-accelerate-innovation-and-promote-trustworthiness. Queue size: 389
# 2025-05-12 11:02:42,783 - INFO - 1551423106 - discover_all_urls - Processing 212/988: https://datascience.uchicago.edu/research/ai-science/partnerships/schmidt-faculty-fellows
# 2025-05-12 11:02:43,159 - INFO - 1551423106 - discover_all_urls - Processing 213/987: https://datascience.uchicago.edu/research/advancing-molecular-measurement-with-machine-learning
# 2025-05-12 11:02:43,416 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/research/advancing-molecular-measurement-with-machine-learning. Queue size: 388
# 2025-05-12 11:02:43,518 - INFO - 1551423106 - discover_all_urls - Processing 214/988: https://datascience.uchicago.edu/research/ai-science/partnerships/nitmb
# 2025-05-12 11:02:43,871 - INFO - 1551423106 - discover_all_urls - Processing 215/987: https://datascience.uchicago.edu/events/ai-science-summer-school-2024
# 2025-05-12 11:02:44,305 - INFO - 1551423106 - discover_all_urls - Processing 216/986: https://datascience.uchicago.edu/news/nsf-and-simons-foundation-launch-20-million-national-ai-research-institute-in-astronomy
# 2025-05-12 11:02:44,683 - INFO - 1551423106 - discover_all_urls - Processing 217/985: https://datascience.uchicago.edu/events/ritesh-kumar-uchicago-aiscience-schmidt-fellows-speaker-series
# 2025-05-12 11:02:45,042 - INFO - 1551423106 - discover_all_urls - Processing 218/984: https://datascience.uchicago.edu/insights/teaching-materials-to-adapt
# 2025-05-12 11:02:45,408 - INFO - 1551423106 - discover_all_urls - Processing 219/983: https://datascience.uchicago.edu/insights/finding-the-likely-causes-when-potential-explanatory-factors-look-alike
# 2025-05-12 11:02:45,767 - INFO - 1551423106 - discover_all_urls - Processing 220/982: https://datascience.uchicago.edu/research/automating-electron-microscopy-with-ai
# 2025-05-12 11:02:46,029 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/research/automating-electron-microscopy-with-ai. Queue size: 382
# 2025-05-12 11:02:46,131 - INFO - 1551423106 - discover_all_urls - Processing 221/983: https://datascience.uchicago.edu/insights/spatial-immunity-a-new-perspective-enabled-by-computer-vision
# 2025-05-12 11:02:46,494 - INFO - 1551423106 - discover_all_urls - Processing 222/982: https://datascience.uchicago.edu/news/new-rfp-for-ai-science-collaborations-with-ttic-weizmann-institute
# 2025-05-12 11:02:46,850 - INFO - 1551423106 - discover_all_urls - Processing 223/981: https://datascience.uchicago.edu/research/ai-science/people
# 2025-05-12 11:02:47,234 - INFO - 1551423106 - discover_all_urls - Processing 224/980: https://datascience.uchicago.edu/research/real-time-adaptive-deep-learning-with-system-on-chip-devices-for-discovery-science
# 2025-05-12 11:02:47,594 - INFO - 1551423106 - discover_all_urls - Processing 225/979: https://datascience.uchicago.edu/events/aiscience-hackathon
# 2025-05-12 11:02:47,959 - INFO - 1551423106 - discover_all_urls - Processing 226/978: https://datascience.uchicago.edu/insights/the-ai-powered-pathway-to-advanced-catalyst-development
# 2025-05-12 11:02:48,222 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/insights/the-ai-powered-pathway-to-advanced-catalyst-development. Queue size: 377
# 2025-05-12 11:02:48,323 - INFO - 1551423106 - discover_all_urls - Processing 227/979: https://datascience.uchicago.edu/insights/from-protein-structures-to-clean-energy-materials-to-cancer-therapies-using-ai-to-understand-and-exploit-x-ray-damage-effects
# 2025-05-12 11:02:48,784 - INFO - 1551423106 - discover_all_urls - Processing 228/978: https://datascience.uchicago.edu/insights/towards-new-physics-at-future-colliders-machine-learning-optimized-detector-and-accelerator-design
# ...
# 2025-05-12 11:12:29,703 - INFO - 1551423106 - discover_all_urls - Processing 1225/1293: https://datascience.uchicago.edu/news/neurips-2023-award-winning-paper-by-dsi-faculty-bo-li-decodingtrust-provides-a-comprehensive-framework-for-assessing-trustworthiness-of-gpt-models
# 2025-05-12 11:12:30,930 - INFO - 1551423106 - discover_all_urls - Processing 1226/1292: https://datascience.uchicago.edu/people/jibang-wu
# 2025-05-12 11:12:31,871 - ERROR - 4278812963 - get_page_content_and_type - HTTP error fetching https://datascience.uchicago.edu/people/jibang-wu: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/people/jibang-wu
# 2025-05-12 11:12:31,872 - WARNING - 1551423106 - discover_all_urls - No content fetched for https://datascience.uchicago.edu/people/jibang-wu. Skipping link extraction.
# 2025-05-12 11:12:31,873 - INFO - 1551423106 - discover_all_urls - Processing 1227/1291: https://datascience.uchicago.edu/events/dsi-postdoc-info-session
# 2025-05-12 11:12:32,221 - INFO - 1551423106 - discover_all_urls - Processing 1228/1290: https://datascience.uchicago.edu/events/milind-tambe-harvard-ai-for-social-impact
# 2025-05-12 11:12:32,584 - INFO - 1551423106 - discover_all_urls - Processing 1229/1289: https://datascience.uchicago.edu/events/vera-liao-microsoft-research-human-centered-ai-transparency
# 2025-05-12 11:12:32,955 - INFO - 1551423106 - discover_all_urls - Processing 1230/1288: https://datascience.uchicago.edu/events/adam-klivans-ut-austin-testable-learning
# 2025-05-12 11:12:33,316 - INFO - 1551423106 - discover_all_urls - Processing 1231/1287: https://datascience.uchicago.edu/events/maryam-fazel-washington-flat-minima
# 2025-05-12 11:12:33,684 - INFO - 1551423106 - discover_all_urls - Processing 1232/1286: https://datascience.uchicago.edu/events/ask-a-student-in-ms-in-applied-data-science-3
# 2025-05-12 11:12:34,027 - INFO - 1551423106 - discover_all_urls - Processing 1233/1285: https://datascience.uchicago.edu/2019/04/10/cdac-announces-inaugural-cohort-of-data-science-discovery-projects
# 2025-05-12 11:12:34,252 - ERROR - 4278812963 - get_page_content_and_type - HTTP error fetching https://datascience.uchicago.edu/2019/04/10/cdac-announces-inaugural-cohort-of-data-science-discovery-projects: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/2019/04/10/cdac-announces-inaugural-cohort-of-data-science-discovery-projects
# 2025-05-12 11:12:34,253 - WARNING - 1551423106 - discover_all_urls - No content fetched for https://datascience.uchicago.edu/2019/04/10/cdac-announces-inaugural-cohort-of-data-science-discovery-projects. Skipping link extraction.
# 2025-05-12 11:12:34,254 - INFO - 1551423106 - discover_all_urls - Processing 1234/1284: https://datascience.uchicago.edu/events/consumer-spending-during-unemployment-with-peter-ganong-uchicago
# 2025-05-12 11:12:34,598 - INFO - 1551423106 - discover_all_urls - Processing 1235/1283: https://datascience.uchicago.edu/news/the-world-awaits
# 2025-05-12 11:12:35,679 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/news/the-world-awaits. Queue size: 25
# 2025-05-12 11:12:35,780 - INFO - 1551423106 - discover_all_urls - Processing 1236/1284: https://datascience.uchicago.edu/news/national-labs-enlist-uchicago-students-for-help-on-big-data-projects
# 2025-05-12 11:12:36,850 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/news/national-labs-enlist-uchicago-students-for-help-on-big-data-projects. Queue size: 25
# 2025-05-12 11:12:36,952 - INFO - 1551423106 - discover_all_urls - Processing 1237/1285: https://datascience.uchicago.edu/news/masters-in-applied-data-science-summer-2023-capstone-winner
# 2025-05-12 11:12:38,119 - INFO - 1551423106 - discover_all_urls - Processing 1238/1284: https://datascience.uchicago.edu/people/michael-xiao-mba
# 2025-05-12 11:12:39,149 - ERROR - 4278812963 - get_page_content_and_type - HTTP error fetching https://datascience.uchicago.edu/people/michael-xiao-mba: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/people/michael-xiao-mba
# 2025-05-12 11:12:39,150 - WARNING - 1551423106 - discover_all_urls - No content fetched for https://datascience.uchicago.edu/people/michael-xiao-mba. Skipping link extraction.
# 2025-05-12 11:12:39,155 - INFO - 1551423106 - discover_all_urls - Processing 1239/1283: https://datascience.uchicago.edu/events/rising-stars-in-data-science-workshop-autumn-2023
# 2025-05-12 11:12:40,734 - INFO - 1551423106 - discover_all_urls - Processing 1240/1282: https://datascience.uchicago.edu/news/new-2023-academic-school-year-brings-new-postdoctoral-researchers-to-the-data-science-institute
# 2025-05-12 11:12:41,994 - INFO - 1551423106 - discover_all_urls - Processing 1241/1281: https://datascience.uchicago.edu/internet-frontiers-and-opportunities-workshop
# 2025-05-12 11:12:43,062 - INFO - 1551423106 - discover_all_urls - Processing 1242/1280: https://datascience.uchicago.edu/events/cam-dsi-joint-colloquium-per-gunnar-martinsson
# 2025-05-12 11:12:44,188 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/events/cam-dsi-joint-colloquium-per-gunnar-martinsson. Queue size: 20
# 2025-05-12 11:12:44,289 - INFO - 1551423106 - discover_all_urls - Processing 1243/1281: https://datascience.uchicago.edu/news/spring-2024-distinguished-speaker-series
# 2025-05-12 11:12:44,578 - INFO - 1551423106 - discover_all_urls - Found 3 new links on https://datascience.uchicago.edu/news/spring-2024-distinguished-speaker-series. Queue size: 22
# 2025-05-12 11:12:44,679 - INFO - 1551423106 - discover_all_urls - Processing 1244/1286: https://datascience.uchicago.edu/news/autumn-2022-distinguished-speaker-series
# 2025-05-12 11:12:45,808 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/news/autumn-2022-distinguished-speaker-series. Queue size: 23
# 2025-05-12 11:12:45,909 - INFO - 1551423106 - discover_all_urls - Processing 1245/1289: https://datascience.uchicago.edu/events/phd-in-data-science-online-information-session
# 2025-05-12 11:12:47,166 - INFO - 1551423106 - discover_all_urls - Processing 1246/1288: https://datascience.uchicago.edu/events
# 2025-05-12 11:12:48,213 - INFO - 1551423106 - discover_all_urls - Processing 1247/1287: https://datascience.uchicago.edu/rfp-winter19
# 2025-05-12 11:12:49,151 - ERROR - 4278812963 - get_page_content_and_type - HTTP error fetching https://datascience.uchicago.edu/rfp-winter19: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/rfp-winter19
# 2025-05-12 11:12:49,153 - WARNING - 1551423106 - discover_all_urls - No content fetched for https://datascience.uchicago.edu/rfp-winter19. Skipping link extraction.
# 2025-05-12 11:12:49,154 - INFO - 1551423106 - discover_all_urls - Processing 1248/1286: https://datascience.uchicago.edu/news/cdac-opens-autumn-2019-discovery-grant-call-for-proposals
# 2025-05-12 11:12:50,300 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/news/cdac-opens-autumn-2019-discovery-grant-call-for-proposals. Queue size: 20
# 2025-05-12 11:12:50,402 - INFO - 1551423106 - discover_all_urls - Processing 1249/1287: https://datascience.uchicago.edu/insights/happy-2020-from-cdac
# 2025-05-12 11:12:51,532 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/insights/happy-2020-from-cdac. Queue size: 21
# 2025-05-12 11:12:51,634 - INFO - 1551423106 - discover_all_urls - Processing 1250/1290: https://datascience.uchicago.edu/news/announcing-the-cdac-winter-2021-distinguished-speaker-series
# 2025-05-12 11:12:52,883 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/news/announcing-the-cdac-winter-2021-distinguished-speaker-series. Queue size: 21
# 2025-05-12 11:12:52,985 - INFO - 1551423106 - discover_all_urls - Processing 1251/1291: https://datascience.uchicago.edu/events/cdac-summer-lab-broadbandproject
# 2025-05-12 11:12:54,239 - INFO - 1551423106 - discover_all_urls - Processing 1252/1290: https://datascience.uchicago.edu/insights/internet-access-map-for-american-cities
# 2025-05-12 11:12:55,492 - INFO - 1551423106 - discover_all_urls - Processing 1253/1289: https://datascience.uchicago.edu/news/security-online-speech-and-a-better-web-for-all-prof-nick-feamster-joins-cdac-and-uchicago-cs
# 2025-05-12 11:12:56,682 - INFO - 1551423106 - discover_all_urls - Processing 1254/1288: https://datascience.uchicago.edu/insights/network-microscope
# 2025-05-12 11:12:57,891 - INFO - 1551423106 - discover_all_urls - Processing 1255/1287: http://datascience.uchicago.edu/engage/data-science@uchicago.edu
# 2025-05-12 11:12:59,413 - ERROR - 4278812963 - get_page_content_and_type - HTTP error fetching http://datascience.uchicago.edu/engage/data-science@uchicago.edu: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/engage/data-science@uchicago.edu
# 2025-05-12 11:12:59,414 - WARNING - 1551423106 - discover_all_urls - No content fetched for http://datascience.uchicago.edu/engage/data-science@uchicago.edu. Skipping link extraction.
# 2025-05-12 11:12:59,415 - INFO - 1551423106 - discover_all_urls - Processing 1256/1286: https://datascience.uchicago.edu/events/ms-in-applied-data-science-information-session-in-person-program
# 2025-05-12 11:13:00,668 - INFO - 1551423106 - discover_all_urls - Processing 1257/1285: https://datascience.uchicago.edu/events/ask-a-student-in-ms-in-applied-data-science-10
# 2025-05-12 11:13:01,736 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/events/ask-a-student-in-ms-in-applied-data-science-10. Queue size: 15
# 2025-05-12 11:13:01,838 - INFO - 1551423106 - discover_all_urls - Processing 1258/1286: https://datascience.uchicago.edu/insights/science-friday-your-smart-tv-is-watching-you
# 2025-05-12 11:13:03,159 - INFO - 1551423106 - discover_all_urls - Processing 1259/1285: https://datascience.uchicago.edu/events/first-annual-uchicago-transit-datathon
# 2025-05-12 11:13:04,403 - INFO - 1551423106 - discover_all_urls - Processing 1260/1284: https://datascience.uchicago.edu/news/2023-rising-stars-in-data-science-visit-uchicago-to-advance-their-post-doctoral-careers
# 2025-05-12 11:13:05,598 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/news/2023-rising-stars-in-data-science-visit-uchicago-to-advance-their-post-doctoral-careers. Queue size: 13
# 2025-05-12 11:13:05,699 - INFO - 1551423106 - discover_all_urls - Processing 1261/1285: https://datascience.uchicago.edu/people/rahim-rasool
# 2025-05-12 11:13:06,646 - ERROR - 4278812963 - get_page_content_and_type - HTTP error fetching https://datascience.uchicago.edu/people/rahim-rasool: 404 Client Error: Not Found for url: https://datascience.uchicago.edu/people/rahim-rasool
# 2025-05-12 11:13:06,648 - WARNING - 1551423106 - discover_all_urls - No content fetched for https://datascience.uchicago.edu/people/rahim-rasool. Skipping link extraction.
# 2025-05-12 11:13:06,649 - INFO - 1551423106 - discover_all_urls - Processing 1262/1284: https://datascience.uchicago.edu/events/cam-statistics-dsi-joint-colloquium-anna-gilbert
# 2025-05-12 11:13:07,795 - INFO - 1551423106 - discover_all_urls - Processing 1263/1283: https://datascience.uchicago.edu/events/inderjit-dhillon-uta
# 2025-05-12 11:13:08,185 - INFO - 1551423106 - discover_all_urls - Processing 1264/1282: https://datascience.uchicago.edu/events/brandon-stewart-princeton
# 2025-05-12 11:13:09,472 - INFO - 1551423106 - discover_all_urls - Processing 1265/1281: https://datascience.uchicago.edu/events/irina-rish-montreal
# 2025-05-12 11:13:10,724 - INFO - 1551423106 - discover_all_urls - Processing 1266/1280: https://datascience.uchicago.edu/events/bo-li-uiuc-trustworthy-federated-learning-robustness-fairness-privacy-and-their-interconnections
# 2025-05-12 11:13:11,957 - INFO - 1551423106 - discover_all_urls - Processing 1267/1279: https://datascience.uchicago.edu/events/james-zou-stanford-clinical-trials-for-ai-and-ai-for-clinical-trials
# 2025-05-12 11:13:13,195 - INFO - 1551423106 - discover_all_urls - Processing 1268/1278: https://datascience.uchicago.edu/events/cdac-discovery-grant-proposers-day
# 2025-05-12 11:13:13,566 - INFO - 1551423106 - discover_all_urls - Processing 1269/1277: https://datascience.uchicago.edu/events/cdac-iot-lab-workshop
# 2025-05-12 11:13:14,663 - INFO - 1551423106 - discover_all_urls - Found 2 new links on https://datascience.uchicago.edu/events/cdac-iot-lab-workshop. Queue size: 6
# 2025-05-12 11:13:14,771 - INFO - 1551423106 - discover_all_urls - Processing 1270/1280: https://datascience.uchicago.edu/engage/internships
# 2025-05-12 11:13:15,895 - INFO - 1551423106 - discover_all_urls - Processing 1271/1279: https://datascience.uchicago.edu/insights/olga-russakovsky-princeton-fairness-in-visual-recognition
# 2025-05-12 11:13:17,011 - INFO - 1551423106 - discover_all_urls - Found 1 new links on https://datascience.uchicago.edu/insights/olga-russakovsky-princeton-fairness-in-visual-recognition. Queue size: 5
# 2025-05-12 11:13:17,113 - INFO - 1551423106 - discover_all_urls - Processing 1272/1280: https://datascience.uchicago.edu/news/the-ms-in-applied-data-science-program-celebrates-10-years
# 2025-05-12 11:13:18,273 - INFO - 1551423106 - discover_all_urls - Processing 1273/1279: https://datascience.uchicago.edu/events/rising-stars-in-data-science-information-session-2
# 2025-05-12 11:13:19,538 - INFO - 1551423106 - discover_all_urls - Processing 1274/1278: https://datascience.uchicago.edu/insights/iot-inspector
# 2025-05-12 11:13:20,682 - INFO - 1551423106 - discover_all_urls - Processing 1275/1277: https://datascience.uchicago.edu/insights/discovering-the-data-all-around-us-the-cdac-iot-lab
# 2025-05-12 11:13:21,892 - INFO - 1551423106 - discover_all_urls - Processing 1276/1276: https://datascience.uchicago.edu/events/cdac-distinguished-speaker-series-olga-russakovsky-princeton
# 2025-05-12 11:13:23,063 - INFO - 1551423106 - discover_all_urls - Discovery finished. Total unique relevant URLs found: 1276
# 2025-05-12 11:13:23,073 - INFO - 862450982 - save_discovered_links - Successfully saved 1276 links to ../data\discovered_links.json
# 2025-05-12 11:13:23,074 - INFO - 583492747 - <module> -
# --- Link Discovery Summary ---
# 2025-05-12 11:13:23,075 - INFO - 583492747 - <module> - Discovery date: 2025-05-12T11:13:23.075457
# 2025-05-12 11:13:23,076 - INFO - 583492747 - <module> - Total links found: 1276
# 2025-05-12 11:13:23,077 - INFO - 583492747 - <module> -
# Sample links (first 10):
# 2025-05-12 11:13:23,078 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/
# 2025-05-12 11:13:23,079 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/about/contact
# 2025-05-12 11:13:23,081 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/engage/data-science@uchicago.edu
# 2025-05-12 11:13:23,081 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/engage/data4all
# 2025-05-12 11:13:23,083 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/engage/fellowships
# 2025-05-12 11:13:23,084 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/news-events/events
# 2025-05-12 11:13:23,085 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/news-events/insights
# 2025-05-12 11:13:23,087 - INFO - 583492747 - <module> -   - http://datascience.uchicago.edu/news-events/news
# 2025-05-12 11:13:23,088 - INFO - 583492747 - <module> -   - https://datascience.uchicago.edu/
# 2025-05-12 11:13:23,089 - INFO - 583492747 - <module> -   - https://datascience.uchicago.edu/11th-hour-project
# 2025-05-12 11:13:23,089 - INFO - 583492747 - <module> -   ...
# 2025-05-12 11:13:23,090 - INFO - 583492747 - <module> - --- Link Discovery Completed in 721.22 seconds ---
